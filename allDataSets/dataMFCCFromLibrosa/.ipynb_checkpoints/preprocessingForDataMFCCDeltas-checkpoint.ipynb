# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
import seaborn as sns

# %%
dataMFCC = pd.read_csv("dataForMFCCDeltas.csv",usecols=lambda column: column != 'filename')

# %%
dataMFCC.head()
# Out:
#    mfcc1_delta  mfcc2_delta  mfcc3_delta  mfcc4_delta  mfcc5_delta  \
# 0     0.105265     0.006372     0.029301    -0.007364     0.029296
# 1     0.104148    -0.016984     0.013990     0.001350     0.002648
# 2     0.029883     0.028489    -0.009955     0.002261    -0.003852
# 3    -0.018792     0.010139     0.014760     0.006951     0.015445
# 4     0.056777     0.052818    -0.010210    -0.004239    -0.001627
#
#    mfcc6_delta  mfcc7_delta  mfcc8_delta  mfcc9_delta  mfcc10_delta  ...  \
# 0     0.032802     0.009167    -0.024216    -0.010839      0.014431  ...
# 1    -0.009762    -0.011100     0.001414    -0.009450     -0.021455  ...
# 2     0.027426     0.019771     0.010638     0.019054      0.008339  ...
# 3     0.017319    -0.025722    -0.025269    -0.018115     -0.001459  ...
# 4     0.034322    -0.005006     0.008210    -0.004956      0.004015  ...
#
#    mfcc12_delta  mfcc13_delta  mfcc14_delta  mfcc15_delta  mfcc16_delta  \
# 0     -0.009615     -0.006449     -0.022793     -0.029550     -0.035698
# 1     -0.002430     -0.005793     -0.013060     -0.011172      0.002258
# 2      0.006772      0.004722      0.002172      0.008963      0.016858
# 3     -0.003096     -0.005070     -0.003745     -0.017687     -0.029552
# 4     -0.004104      0.000187      0.011135     -0.006230     -0.003322
#
#    mfcc17_delta  mfcc18_delta  mfcc19_delta  mfcc20_delta  genre
# 0     -0.004061      0.015403      0.027763      0.015784    pop
# 1     -0.003963     -0.001441     -0.002932      0.000430    pop
# 2      0.007511      0.007263      0.006925      0.013436    pop
# 3      0.005382      0.010811      0.009575      0.001937    pop
# 4      0.004229     -0.003618     -0.006311      0.007206    pop
#
# [5 rows x 21 columns]

# %% [markdown]
# # Updating datasets y-columns

# %%
mappingGenresToIntegers = {
    'pop': 0,
    'metal': 1,
    'disco': 2,
    'blues': 3,
    'reggae': 4,
    'classical': 5,
    'rock': 6,
    'hiphop': 7,
    'country': 8,
    'jazz': 9
}


dataMFCC['genre'] = dataMFCC['genre'].map(mappingGenresToIntegers)
dataMFCC.head()
# Out:
#    mfcc1_delta  mfcc2_delta  mfcc3_delta  mfcc4_delta  mfcc5_delta  \
# 0     0.105265     0.006372     0.029301    -0.007364     0.029296
# 1     0.104148    -0.016984     0.013990     0.001350     0.002648
# 2     0.029883     0.028489    -0.009955     0.002261    -0.003852
# 3    -0.018792     0.010139     0.014760     0.006951     0.015445
# 4     0.056777     0.052818    -0.010210    -0.004239    -0.001627
#
#    mfcc6_delta  mfcc7_delta  mfcc8_delta  mfcc9_delta  mfcc10_delta  ...  \
# 0     0.032802     0.009167    -0.024216    -0.010839      0.014431  ...
# 1    -0.009762    -0.011100     0.001414    -0.009450     -0.021455  ...
# 2     0.027426     0.019771     0.010638     0.019054      0.008339  ...
# 3     0.017319    -0.025722    -0.025269    -0.018115     -0.001459  ...
# 4     0.034322    -0.005006     0.008210    -0.004956      0.004015  ...
#
#    mfcc12_delta  mfcc13_delta  mfcc14_delta  mfcc15_delta  mfcc16_delta  \
# 0     -0.009615     -0.006449     -0.022793     -0.029550     -0.035698
# 1     -0.002430     -0.005793     -0.013060     -0.011172      0.002258
# 2      0.006772      0.004722      0.002172      0.008963      0.016858
# 3     -0.003096     -0.005070     -0.003745     -0.017687     -0.029552
# 4     -0.004104      0.000187      0.011135     -0.006230     -0.003322
#
#    mfcc17_delta  mfcc18_delta  mfcc19_delta  mfcc20_delta  genre
# 0     -0.004061      0.015403      0.027763      0.015784      0
# 1     -0.003963     -0.001441     -0.002932      0.000430      0
# 2      0.007511      0.007263      0.006925      0.013436      0
# 3      0.005382      0.010811      0.009575      0.001937      0
# 4      0.004229     -0.003618     -0.006311      0.007206      0
#
# [5 rows x 21 columns]

# %%
csv_file = 'dataMFCC_genreChangedToNumbers.csv'
dataMFCC.to_csv(csv_file, index=False)

# %% [markdown]
# # Pre-processing

# %% [markdown]
# ## Standard scaling and train_test_split

# %%
X = dataMFCC.iloc[:, :-1]
y = dataMFCC.iloc[:, -1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.15, random_state = 42)

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Using heatmap to see what features are too closely correlated, then removing them as necessary

# %%
corr = X.corr()

mask = corr.abs() > 0.9

plt.figure(figsize=(12,10))

sns.heatmap(corr, center=0, mask=mask, square=True, linewidths=.4, annot=True, fmt=".2f", annot_kws={"size": 7}, cbar_kws={"shrink": .5})
plt.xticks(fontsize = 8)
plt.yticks(fontsize = 8)
plt.show()

# %% [markdown]
# None of the features are really correlated, so we can't really remove any of the features

# %% [markdown]
# ## Randomly choosing features to keep

# %%
columns_to_keep = ['mfcc1_delta', 'mfcc5_delta', 'mfcc10_delta', 'mfcc15_delta', 'mfcc20_delta']
dataReducedColumns = dataMFCC[columns_to_keep]
dataReducedColumns.head()
# Out:
#    mfcc1_delta  mfcc5_delta  mfcc10_delta  mfcc15_delta  mfcc20_delta
# 0     0.105265     0.029296      0.014431     -0.029550      0.015784
# 1     0.104148     0.002648     -0.021455     -0.011172      0.000430
# 2     0.029883    -0.003852      0.008339      0.008963      0.013436
# 3    -0.018792     0.015445     -0.001459     -0.017687      0.001937
# 4     0.056777    -0.001627      0.004015     -0.006230      0.007206

# %%
csv_file = 'dataMFCC_reducedColumnsRandom.csv'
dataReducedColumns.to_csv(csv_file, index=False)

# %% [markdown]
# The chromas in the harmonic are the same as the chromas in the original. So those might not necessarily be needed for this testing.

# %%
columnsToKeep = [col for col in dataHarmonic.columns if 'chroma' not in col]

dataReducedColumns = dataHarmonic[columnsToKeep]
dataReducedColumns.head()
# Out:
#    tonnetz_dim1  tonnetz_dim2  tonnetz_dim3  tonnetz_dim4  tonnetz_dim5  \
# 0      0.092298      0.109638     -0.010165      0.067054      0.038712
# 1     -0.006052      0.068081      0.090119      0.068515     -0.004434
# 2      0.120270     -0.068952     -0.048086     -0.156026      0.007883
# 3      0.093430      0.109086     -0.007735      0.068533      0.040309
# 4     -0.105472     -0.100274      0.085604     -0.095592     -0.005032
#
#    tonnetz_dim6  tonnetz_allDims  spectral_centroid  spectral_bandwidth  \
# 0     -0.048381         0.041526        2578.901672         3093.308123
# 1      0.012794         0.038170        2624.813690         3031.844488
# 2     -0.002300        -0.024535        2914.465143         3189.873176
# 3     -0.048440         0.042530        2579.310087         3091.031145
# 4      0.020751        -0.033336        2849.120174         3124.483585
#
#    spectral_rolloff  ...    mfcc12    mfcc13    mfcc14    mfcc15    mfcc16  \
# 0       6384.120097  ...  0.164212  2.695709  1.318642  0.632315  0.957001
# 1       6244.770462  ...  5.130442  6.827752  3.071533  3.366904 -2.422404
# 2       7086.530518  ...  1.111607 -2.048577 -4.366745 -3.732610 -3.398216
# 3       6375.868200  ...  0.235207  2.670471  1.338333  0.699207  1.112011
# 4       6707.526159  ... -0.269821 -1.642580 -4.781828 -3.302547 -4.714705
#
#      mfcc17    mfcc18    mfcc19    mfcc20  genre
# 0 -1.566437  6.275709  7.807974  6.363476      0
# 1 -2.135466 -3.336569 -0.564991 -3.893568      0
# 2  2.417332  1.289159  7.578645  4.909898      0
# 3 -1.565463  6.195435  7.648764  6.243628      0
# 4 -3.559506 -3.702941 -4.042264  0.333003      0
#
# [5 rows x 32 columns]

# %%
csv_file = 'dataHarmonic_withoutChromas.csv'
dataReducedColumns.to_csv(csv_file, index=False)

# %% [markdown]
# ## Only using features most correlated to genre

# %%
correlationMatrix = dataMFCC.corr()
correlationWithGenre = correlationMatrix['genre']
correlationWithGenre = correlationWithGenre.drop('genre')

# %%
plt.figure(figsize=(20, 6))
sns.barplot(x=correlationWithGenre.index, y=correlationWithGenre.values)
plt.title('Correlation with Genre')
plt.xlabel('Variable')
plt.ylabel('Correlation')
plt.xticks(rotation=45)
plt.show()

# %%
mostPositive5 = correlationWithGenre.nlargest(5)
print(mostPositive5)
# Out:
# mfcc9_delta     0.084736
# mfcc4_delta     0.043431
# mfcc11_delta    0.021566
# mfcc7_delta     0.021441
# mfcc2_delta     0.015084
# Name: genre, dtype: float64

# %%
dataMFCCWithMostCorrelatedFeatures = dataMFCC[['mfcc9_delta', 'mfcc4_delta', 'mfcc11_delta', 'mfcc7_delta', 'mfcc2_delta', 'genre']]
dataMFCCWithMostCorrelatedFeatures.head()
# Out:
#    mfcc9_delta  mfcc4_delta  mfcc11_delta  mfcc7_delta  mfcc2_delta  genre
# 0    -0.010839    -0.007364      0.002031     0.009167     0.006372      0
# 1    -0.009450     0.001350     -0.016301    -0.011100    -0.016984      0
# 2     0.019054     0.002261      0.002389     0.019771     0.028489      0
# 3    -0.018115     0.006951     -0.004117    -0.025722     0.010139      0
# 4    -0.004956    -0.004239     -0.002897    -0.005006     0.052818      0

# %%
csv_file = 'dataMFCC_reducedColumnsBasedOnCorrelationToGenre.csv'
dataMFCCWithMostCorrelatedFeatures.to_csv(csv_file, index=False)

# %% [markdown]
# ## Removing outliers

# %%
columns = list(range(X.shape[1]))
data_in_columns = X.iloc[:, columns]

# %%
fig, axes = plt.subplots(nrows=5, ncols=6, figsize=(20, 12))

for i, ax in enumerate(axes.flat):
    if i < len(columns):
        ax.boxplot(data_in_columns.iloc[:, i])
        ax.set_title(f'{data_in_columns.columns[i]}')
        ax.axhline(y=data_in_columns.iloc[:, i].median(), color='r')
        ax.set_xlabel(data_in_columns.columns[i])
    else:
        ax.set_visible(False)


plt.show()

# %%
thresholds = data_in_columns.quantile([0.25, 0.75])
iqr = 1.5 * (thresholds.loc[0.75] - thresholds.loc[0.25])

dataWithoutOutliers = dataMFCC.copy()

for col in data_in_columns.columns:
    lower = thresholds.loc[0.25, col] - iqr.loc[col]
    upper = thresholds.loc[0.75, col] + iqr.loc[col]
    dataWithoutOutliers[col] = np.where((dataWithoutOutliers[col] < lower) | (dataWithoutOutliers[col] > upper), np.nan, dataWithoutOutliers[col])

dataWithoutOutliers = dataWithoutOutliers.dropna()

# %%
dataWithoutOutliers.shape
# Out:
# (719, 21)

# %%
X = dataWithoutOutliers.iloc[:, :-1]
y = dataWithoutOutliers.iloc[:, -1]

columns = list(range(X.shape[1]))
data_in_columns = X.iloc[:, columns]

fig, axes = plt.subplots(nrows=5, ncols=6, figsize=(20, 12))

for i, ax in enumerate(axes.flat):
    if i < len(columns):
        ax.boxplot(data_in_columns.iloc[:, i])
        ax.set_title(f'{data_in_columns.columns[i]}')
        ax.axhline(y=data_in_columns.iloc[:, i].median(), color='r')
        ax.set_xlabel(data_in_columns.columns[i])
    else:
        ax.set_visible(False)


plt.show()

# %%
dataWithoutOutliers.head()
# Out:
#    mfcc1_delta  mfcc2_delta  mfcc3_delta  mfcc4_delta  mfcc5_delta  \
# 1     0.104148    -0.016984     0.013990     0.001350     0.002648
# 2     0.029883     0.028489    -0.009955     0.002261    -0.003852
# 4     0.056777     0.052818    -0.010210    -0.004239    -0.001627
# 5     0.094968    -0.004627     0.005744    -0.010092     0.012552
# 7    -0.030126     0.017896     0.010920     0.025707     0.018705
#
#    mfcc6_delta  mfcc7_delta  mfcc8_delta  mfcc9_delta  mfcc10_delta  ...  \
# 1    -0.009762    -0.011100     0.001414    -0.009450     -0.021455  ...
# 2     0.027426     0.019771     0.010638     0.019054      0.008339  ...
# 4     0.034322    -0.005006     0.008210    -0.004956      0.004015  ...
# 5    -0.002975    -0.006517     0.009945     0.005906     -0.005631  ...
# 7    -0.029974    -0.033754     0.009268     0.007275      0.014459  ...
#
#    mfcc12_delta  mfcc13_delta  mfcc14_delta  mfcc15_delta  mfcc16_delta  \
# 1     -0.002430     -0.005793     -0.013060     -0.011172      0.002258
# 2      0.006772      0.004722      0.002172      0.008963      0.016858
# 4     -0.004104      0.000187      0.011135     -0.006230     -0.003322
# 5     -0.003279     -0.010546      0.013937      0.014227      0.006542
# 7      0.006774      0.004707      0.000397     -0.013007      0.007715
#
#    mfcc17_delta  mfcc18_delta  mfcc19_delta  mfcc20_delta  genre
# 1     -0.003963     -0.001441     -0.002932      0.000430      0
# 2      0.007511      0.007263      0.006925      0.013436      0
# 4      0.004229     -0.003618     -0.006311      0.007206      0
# 5      0.003266      0.007920      0.021270     -0.004793      0
# 7      0.008366      0.000097      0.005132      0.000487      0
#
# [5 rows x 21 columns]

# %%
dataWithoutOutliers.shape
# Out:
# (719, 21)

# %%
csv_file = 'dataMFCC_withoutOutliers.csv'
dataWithoutOutliers.to_csv(csv_file, index=False)

# %%
labels = [
    'pop',
    'metal',
    'disco',
    'blues',
    'reggae',
    'classical',
    'rock',
    'hiphop',
    'country',
    'jazz'
]

sizes = np.unique(y,return_counts=True)[1]

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%')

plt.show()

# %% [markdown]
# ## Only testing with certain genres

# %% [markdown]
# ### Part 1 - Randomly separating the genres

# %%
dataMetalOrReggae = dataMFCC[dataMFCC.iloc[:, -1].isin([1, 4])]
dataMetalOrReggae.head()
# Out:
#      mfcc1_delta  mfcc2_delta  mfcc3_delta  mfcc4_delta  mfcc5_delta  \
# 100    -0.007740     0.000424     0.018453    -0.016233     0.008984
# 101    -0.004941     0.019665    -0.032306     0.011998     0.009959
# 102     0.114248    -0.002181     0.009979    -0.028579    -0.003646
# 103    -0.064218     0.021266     0.056335     0.000604     0.002357
# 104    -0.032632     0.014964    -0.011011     0.012032    -0.007532
#
#      mfcc6_delta  mfcc7_delta  mfcc8_delta  mfcc9_delta  mfcc10_delta  ...  \
# 100    -0.003116     0.003809    -0.018103    -0.002964     -0.009380  ...
# 101    -0.012443     0.006068    -0.004864    -0.001224      0.002639  ...
# 102     0.000667     0.008253     0.014598    -0.014480      0.019058  ...
# 103     0.010728     0.001069    -0.006910    -0.004032     -0.004331  ...
# 104     0.006849     0.007972     0.004758     0.003788      0.001223  ...
#
#      mfcc12_delta  mfcc13_delta  mfcc14_delta  mfcc15_delta  mfcc16_delta  \
# 100      0.003070      0.007688     -0.002197      0.001516      0.002101
# 101     -0.008322     -0.002254     -0.004339      0.003675      0.002535
# 102      0.019412     -0.003560      0.009675      0.000855      0.006437
# 103     -0.000132      0.013035      0.004421      0.000537     -0.002019
# 104     -0.006933     -0.002069     -0.006992     -0.006086      0.005855
#
#      mfcc17_delta  mfcc18_delta  mfcc19_delta  mfcc20_delta  genre
# 100     -0.003165     -0.001079     -0.004829     -0.002381      1
# 101     -0.002220     -0.003242      0.012748     -0.008764      1
# 102     -0.008085      0.002063      0.002783      0.002017      1
# 103      0.007896      0.001635      0.002465     -0.010823      1
# 104      0.006269     -0.003536      0.007573      0.002089      1
#
# [5 rows x 21 columns]

# %%
csv_file = 'dataMFCC_metal_reggae.csv'
dataMetalOrReggae.to_csv(csv_file, index=False)

# %%
dataPopOrDisco = dataMFCC[dataMFCC.iloc[:, -1].isin([0, 2])]
dataPopOrDisco.head()
# Out:
#    mfcc1_delta  mfcc2_delta  mfcc3_delta  mfcc4_delta  mfcc5_delta  \
# 0     0.105265     0.006372     0.029301    -0.007364     0.029296
# 1     0.104148    -0.016984     0.013990     0.001350     0.002648
# 2     0.029883     0.028489    -0.009955     0.002261    -0.003852
# 3    -0.018792     0.010139     0.014760     0.006951     0.015445
# 4     0.056777     0.052818    -0.010210    -0.004239    -0.001627
#
#    mfcc6_delta  mfcc7_delta  mfcc8_delta  mfcc9_delta  mfcc10_delta  ...  \
# 0     0.032802     0.009167    -0.024216    -0.010839      0.014431  ...
# 1    -0.009762    -0.011100     0.001414    -0.009450     -0.021455  ...
# 2     0.027426     0.019771     0.010638     0.019054      0.008339  ...
# 3     0.017319    -0.025722    -0.025269    -0.018115     -0.001459  ...
# 4     0.034322    -0.005006     0.008210    -0.004956      0.004015  ...
#
#    mfcc12_delta  mfcc13_delta  mfcc14_delta  mfcc15_delta  mfcc16_delta  \
# 0     -0.009615     -0.006449     -0.022793     -0.029550     -0.035698
# 1     -0.002430     -0.005793     -0.013060     -0.011172      0.002258
# 2      0.006772      0.004722      0.002172      0.008963      0.016858
# 3     -0.003096     -0.005070     -0.003745     -0.017687     -0.029552
# 4     -0.004104      0.000187      0.011135     -0.006230     -0.003322
#
#    mfcc17_delta  mfcc18_delta  mfcc19_delta  mfcc20_delta  genre
# 0     -0.004061      0.015403      0.027763      0.015784      0
# 1     -0.003963     -0.001441     -0.002932      0.000430      0
# 2      0.007511      0.007263      0.006925      0.013436      0
# 3      0.005382      0.010811      0.009575      0.001937      0
# 4      0.004229     -0.003618     -0.006311      0.007206      0
#
# [5 rows x 21 columns]

# %%
csv_file = 'dataMFCC_pop_disco.csv'
dataPopOrDisco.to_csv(csv_file, index=False)

# %%
dataRockOrCountry = dataMFCC[dataMFCC.iloc[:, -1].isin([6, 8])]
dataRockOrCountry.head()
# Out:
#      mfcc1_delta  mfcc2_delta  mfcc3_delta  mfcc4_delta  mfcc5_delta  \
# 600    -0.005154    -0.005455     0.000986    -0.011260    -0.009687
# 601    -0.052304    -0.020679    -0.016109     0.002689     0.001950
# 602     0.032721     0.025370    -0.034743    -0.003017    -0.004558
# 603    -0.022730     0.035428    -0.032756     0.009746     0.004403
# 604    -0.141731     0.054331     0.008807    -0.006166     0.026011
#
#      mfcc6_delta  mfcc7_delta  mfcc8_delta  mfcc9_delta  mfcc10_delta  ...  \
# 600    -0.008698    -0.000343    -0.000300    -0.003892     -0.002191  ...
# 601     0.008493    -0.000837    -0.009257    -0.015656     -0.003091  ...
# 602    -0.011386    -0.007650    -0.004011    -0.006524     -0.007554  ...
# 603    -0.008227    -0.009747    -0.003310    -0.008711      0.002987  ...
# 604     0.000642     0.021712    -0.003546     0.028372     -0.009709  ...
#
#      mfcc12_delta  mfcc13_delta  mfcc14_delta  mfcc15_delta  mfcc16_delta  \
# 600     -0.002309     -0.003704     -0.006135     -0.005285     -0.000951
# 601      0.005425     -0.002114      0.001360     -0.005645     -0.014303
# 602     -0.003566      0.003179     -0.007020      0.008418     -0.000367
# 603     -0.008632      0.005729      0.002388     -0.004407     -0.004737
# 604     -0.005873      0.001298      0.001475      0.013143     -0.018419
#
#      mfcc17_delta  mfcc18_delta  mfcc19_delta  mfcc20_delta  genre
# 600      0.002425      0.003569     -0.000878     -0.007702      6
# 601     -0.003137     -0.010266     -0.007958     -0.000697      6
# 602      0.005718      0.004053      0.002848     -0.009631      6
# 603     -0.003280     -0.002055     -0.003736     -0.002386      6
# 604     -0.008625      0.004331      0.009298     -0.010813      6
#
# [5 rows x 21 columns]

# %%
csv_file = 'dataMFCC_rock_country.csv'
dataRockOrCountry.to_csv(csv_file, index=False)

# %% [markdown]
# ### Using PCA and TSNE to analyze which features to keep

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA, FactorAnalysis

X = dataMFCC.iloc[:, :-1]
y = dataMFCC.iloc[:, -1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True, random_state=123)

sc = StandardScaler()
X_scaled_train = sc.fit_transform(X_train)
X_scaled_test = sc.transform(X_test)

pca = PCA()
transformed = pca.fit_transform(X_scaled_train)

exp_var_pca = pca.explained_variance_ratio_
cum_sum_eigenvalues = np.cumsum(exp_var_pca)

plt.bar(range(0,len(exp_var_pca)), exp_var_pca, alpha=0.5, align='center')
plt.ylabel('Explained variance ratio')
plt.xlabel('Principal component index')
plt.title("Individual explained variance")
plt.tight_layout()
plt.show()

# %%
plt.step(range(0,len(cum_sum_eigenvalues)), cum_sum_eigenvalues, where='mid',label='Cumulative explained variance')
plt.hlines(0.8, xmin=0, xmax=len(cum_sum_eigenvalues), color='red', linewidth=.6)
plt.hlines(0.9, xmin=0, xmax=len(cum_sum_eigenvalues), color='red', linewidth=.6)
plt.ylabel('Explained variance ratio')
plt.xlabel('Principal component index')
plt.title("Cumulative explained variance")
plt.show()

# %% [markdown]
# The main difference between the two plots lies in what they visualize:
#
# Individual Explained Variance Plot:
#
# The first plot, generated with plt.bar(), displays the explained variance ratio for each individual principal component.
# Each bar in this plot represents the proportion of total variance explained by a single principal component.
# This plot helps in understanding the relative importance of each principal component in explaining the variance in the data.
# Cumulative Explained Variance Plot:
#
# The second plot, created with plt.step(), illustrates the cumulative explained variance ratio.
# It shows how much of the total variance in the dataset is explained as the number of principal components increases.
# The steps in this plot indicate the incremental contribution of each principal component to the total explained variance.
# Horizontal lines are added at specific percentages (e.g., 80% and 90%) to indicate where certain thresholds of cumulative explained variance are reached.
# This plot helps in determining the number of principal components needed to retain a certain amount of variance in the data, which is crucial for dimensionality reduction or feature selection purposes.

# %%
n_comps = 10
pca = PCA(n_components=n_comps)
X_train_pca_transformed = pca.fit_transform(X_scaled_train)
X_train_pca_transformed = pd.DataFrame(X_train_pca_transformed, index=X_train.index, columns=[f'PCA_{n}' for n in range(1,n_comps+1)])
X_train_pca_transformed.head()
# Out:
#         PCA_1     PCA_2     PCA_3     PCA_4     PCA_5     PCA_6     PCA_7  \
# 498 -3.275269 -0.945266  1.213446 -0.026422 -0.081367 -1.562672  0.561010
# 243  0.395333 -1.573706 -1.395581 -0.765254  0.002570  0.893399 -0.590948
# 314  1.277461 -0.286745 -1.250214  1.595810  0.429904 -0.221618 -0.394203
# 202 -1.039236 -0.890505  1.861796 -0.233451  0.802846 -1.395153  1.304957
# 300  2.975084 -0.260319  1.565462  0.456275 -0.185736  3.242349 -2.649054
#
#         PCA_8     PCA_9    PCA_10
# 498  0.431065 -0.084549  0.443223
# 243 -0.666429  0.266625  0.330184
# 314 -0.285380  0.654685  0.483321
# 202 -0.005190  0.391071 -1.255092
# 300  1.340777 -1.834301  0.740545

# %%
combined = pd.concat([X_train_pca_transformed, y_train], axis=1)
combined.head()
# Out:
#         PCA_1     PCA_2     PCA_3     PCA_4     PCA_5     PCA_6     PCA_7  \
# 498 -3.275269 -0.945266  1.213446 -0.026422 -0.081367 -1.562672  0.561010
# 243  0.395333 -1.573706 -1.395581 -0.765254  0.002570  0.893399 -0.590948
# 314  1.277461 -0.286745 -1.250214  1.595810  0.429904 -0.221618 -0.394203
# 202 -1.039236 -0.890505  1.861796 -0.233451  0.802846 -1.395153  1.304957
# 300  2.975084 -0.260319  1.565462  0.456275 -0.185736  3.242349 -2.649054
#
#         PCA_8     PCA_9    PCA_10  genre
# 498  0.431065 -0.084549  0.443223      4
# 243 -0.666429  0.266625  0.330184      2
# 314 -0.285380  0.654685  0.483321      3
# 202 -0.005190  0.391071 -1.255092      2
# 300  1.340777 -1.834301  0.740545      3

# %%
csv_file = 'dataMFCC_pcaUsingAllFeatures.csv'
combined.to_csv(csv_file, index=False)

# %%
from sklearn.manifold import TSNE
n_comps = 3
tsne = TSNE(n_components=n_comps,perplexity=10)
X_train_tsne_transformed = tsne.fit_transform(X_scaled_train)
X_train_tsne_transformed = pd.DataFrame(X_train_tsne_transformed, index=X_train.index, columns=[f'TSNE_{n}' for n in range(1,n_comps+1)])
X_train_tsne_transformed.head()
# Out:
#         TSNE_1     TSNE_2     TSNE_3
# 498  -7.531846 -24.907255  16.875763
# 243   5.676799  12.990942   9.168717
# 314 -21.623747   6.953266  -9.130245
# 202 -17.342978 -23.898350   1.421531
# 300  30.952682  10.914970 -31.818785

# %%
combinedTSNE = pd.concat([X_train_tsne_transformed, y_train], axis=1)
combinedTSNE.head()
# Out:
#         TSNE_1     TSNE_2     TSNE_3  genre
# 498  -7.531846 -24.907255  16.875763      4
# 243   5.676799  12.990942   9.168717      2
# 314 -21.623747   6.953266  -9.130245      3
# 202 -17.342978 -23.898350   1.421531      2
# 300  30.952682  10.914970 -31.818785      3

# %%
csv_file = 'dataMFCC_tsneUsingAllFeatures.csv'
combinedTSNE.to_csv(csv_file, index=False)

# %% [markdown]
# ### Also going to use PCA and TSNE to figure out which genres to use for most variance in data

# %%
pca = PCA(12)
pca.fit(X_train)
trans_pca = pca.fit_transform(X_test)

genres=['pop', 'metal', 'disco', 'blues', 'reggae', 'classical', 'rock', 'hiphop', 'country', 'jazz']


plt.figure(figsize=(8, 6))
for i in range(10):
    plt.scatter(trans_pca[:,0][y_test==i], trans_pca[:,1][y_test==i], cmap='jet',label=f'{genres[i]}')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()
plt.show()
# Out:
# /var/folders/0x/03rs5r5937b7qn04t9mql34c0000gn/T/ipykernel_23765/4032618176.py:10: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(trans_pca[:,0][y_test==i], trans_pca[:,1][y_test==i], cmap='jet',label=f'{genres[i]}')

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=3,perplexity=10)
trans_tsne = tsne.fit_transform(X_test)

genres=['pop', 'metal', 'disco', 'blues', 'reggae', 'classical', 'rock', 'hiphop', 'country', 'jazz']


plt.figure(figsize=(8, 6))
for i in range(10):
    plt.scatter(trans_tsne[:,0][y_test==i], trans_tsne[:,1][y_test==i], cmap='jet',label=f'{genres[i]}')
plt.legend()
plt.show()
# Out:
# /var/folders/0x/03rs5r5937b7qn04t9mql34c0000gn/T/ipykernel_23765/1015407993.py:10: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(trans_tsne[:,0][y_test==i], trans_tsne[:,1][y_test==i], cmap='jet',label=f'{genres[i]}')

# %% [markdown]
# Based on the two graphs, there don't seem to be any separable genres.

# %% [markdown]
# # Also going to use PCA and TSNE to figure out which genres to use for most variance in data. Same section as above, but this time we'll split dataHarmonic into 2 subsections of genres

# %% [markdown]
# ## genres = ['classical','hiphop','metal', 'disco', 'reggae']

# %%
genreNames = ['classical','hiphop','metal', 'disco', 'reggae']
genreNumbers = [5, 7, 1, 2, 4]

dataSpecifiedGenres = dataMFCC[dataMFCC.iloc[:, -1].isin(genreNumbers)]
dataSpecifiedGenres.shape
# Out:
# (500, 21)

# %%
dataSpecifiedGenres.head()
# Out:
#      mfcc1_delta  mfcc2_delta  mfcc3_delta  mfcc4_delta  mfcc5_delta  \
# 100    -0.007740     0.000424     0.018453    -0.016233     0.008984
# 101    -0.004941     0.019665    -0.032306     0.011998     0.009959
# 102     0.114248    -0.002181     0.009979    -0.028579    -0.003646
# 103    -0.064218     0.021266     0.056335     0.000604     0.002357
# 104    -0.032632     0.014964    -0.011011     0.012032    -0.007532
#
#      mfcc6_delta  mfcc7_delta  mfcc8_delta  mfcc9_delta  mfcc10_delta  ...  \
# 100    -0.003116     0.003809    -0.018103    -0.002964     -0.009380  ...
# 101    -0.012443     0.006068    -0.004864    -0.001224      0.002639  ...
# 102     0.000667     0.008253     0.014598    -0.014480      0.019058  ...
# 103     0.010728     0.001069    -0.006910    -0.004032     -0.004331  ...
# 104     0.006849     0.007972     0.004758     0.003788      0.001223  ...
#
#      mfcc12_delta  mfcc13_delta  mfcc14_delta  mfcc15_delta  mfcc16_delta  \
# 100      0.003070      0.007688     -0.002197      0.001516      0.002101
# 101     -0.008322     -0.002254     -0.004339      0.003675      0.002535
# 102      0.019412     -0.003560      0.009675      0.000855      0.006437
# 103     -0.000132      0.013035      0.004421      0.000537     -0.002019
# 104     -0.006933     -0.002069     -0.006992     -0.006086      0.005855
#
#      mfcc17_delta  mfcc18_delta  mfcc19_delta  mfcc20_delta  genre
# 100     -0.003165     -0.001079     -0.004829     -0.002381      1
# 101     -0.002220     -0.003242      0.012748     -0.008764      1
# 102     -0.008085      0.002063      0.002783      0.002017      1
# 103      0.007896      0.001635      0.002465     -0.010823      1
# 104      0.006269     -0.003536      0.007573      0.002089      1
#
# [5 rows x 21 columns]

# %%
X_specifiedGenres = dataSpecifiedGenres.iloc[:, :-1]
y_specifiedGenres = dataSpecifiedGenres.iloc[:, -1]

X_train_specifiedGenres, X_test_specifiedGenres, y_train_specifiedGenres, y_test_specifiedGenres = train_test_split(X_specifiedGenres, y_specifiedGenres, test_size=0.3, shuffle=True, random_state=123)

sc = StandardScaler()
X_scaled_train = sc.fit_transform(X_train_specifiedGenres)
X_scaled_test = sc.transform(X_test_specifiedGenres)

pca = PCA(10)
pca.fit(X_scaled_train)
trans_pca = pca.fit_transform(X_scaled_test)


plt.figure(figsize=(8, 6))
for i, genreNum in enumerate(genreNumbers):
    plt.scatter(trans_pca[:,0][y_test_specifiedGenres==genreNum], trans_pca[:,1][y_test_specifiedGenres==genreNum], cmap='jet',label=f'{genreNames[i]}')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()
plt.show()
# Out:
# /var/folders/0x/03rs5r5937b7qn04t9mql34c0000gn/T/ipykernel_23765/1749815973.py:17: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(trans_pca[:,0][y_test_specifiedGenres==genreNum], trans_pca[:,1][y_test_specifiedGenres==genreNum], cmap='jet',label=f'{genreNames[i]}')

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2,perplexity=10)
trans_tsne = tsne.fit_transform(X_scaled_test)


plt.figure(figsize=(8, 6))
for i, genre in enumerate(genreNumbers):
    plt.scatter(trans_tsne[:,0][y_test_specifiedGenres==genre], trans_tsne[:,1][y_test_specifiedGenres==genre], cmap='jet',label=f'{genreNames[i]}')
plt.legend()
plt.show()
# Out:
# /var/folders/0x/03rs5r5937b7qn04t9mql34c0000gn/T/ipykernel_23765/1650034879.py:8: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(trans_tsne[:,0][y_test_specifiedGenres==genre], trans_tsne[:,1][y_test_specifiedGenres==genre], cmap='jet',label=f'{genreNames[i]}')

# %% [markdown]
# Based on the PCA and TSNE graphs, there don't seem to be any separable genres

# %% [markdown]
# ## genres = ['pop','rock','country', 'jazz', 'blues']

# %%
genreNames = ['pop','rock','country', 'jazz', 'blues']
genreNumbers = [0, 6, 8, 9, 3]

dataSpecifiedGenres = dataMFCC[dataMFCC.iloc[:, -1].isin(genreNumbers)]
dataSpecifiedGenres.shape
# Out:
# (500, 21)

# %%
dataSpecifiedGenres.head()
# Out:
#    mfcc1_delta  mfcc2_delta  mfcc3_delta  mfcc4_delta  mfcc5_delta  \
# 0     0.105265     0.006372     0.029301    -0.007364     0.029296
# 1     0.104148    -0.016984     0.013990     0.001350     0.002648
# 2     0.029883     0.028489    -0.009955     0.002261    -0.003852
# 3    -0.018792     0.010139     0.014760     0.006951     0.015445
# 4     0.056777     0.052818    -0.010210    -0.004239    -0.001627
#
#    mfcc6_delta  mfcc7_delta  mfcc8_delta  mfcc9_delta  mfcc10_delta  ...  \
# 0     0.032802     0.009167    -0.024216    -0.010839      0.014431  ...
# 1    -0.009762    -0.011100     0.001414    -0.009450     -0.021455  ...
# 2     0.027426     0.019771     0.010638     0.019054      0.008339  ...
# 3     0.017319    -0.025722    -0.025269    -0.018115     -0.001459  ...
# 4     0.034322    -0.005006     0.008210    -0.004956      0.004015  ...
#
#    mfcc12_delta  mfcc13_delta  mfcc14_delta  mfcc15_delta  mfcc16_delta  \
# 0     -0.009615     -0.006449     -0.022793     -0.029550     -0.035698
# 1     -0.002430     -0.005793     -0.013060     -0.011172      0.002258
# 2      0.006772      0.004722      0.002172      0.008963      0.016858
# 3     -0.003096     -0.005070     -0.003745     -0.017687     -0.029552
# 4     -0.004104      0.000187      0.011135     -0.006230     -0.003322
#
#    mfcc17_delta  mfcc18_delta  mfcc19_delta  mfcc20_delta  genre
# 0     -0.004061      0.015403      0.027763      0.015784      0
# 1     -0.003963     -0.001441     -0.002932      0.000430      0
# 2      0.007511      0.007263      0.006925      0.013436      0
# 3      0.005382      0.010811      0.009575      0.001937      0
# 4      0.004229     -0.003618     -0.006311      0.007206      0
#
# [5 rows x 21 columns]

# %%
X_specifiedGenres = dataSpecifiedGenres.iloc[:, :-1]
y_specifiedGenres = dataSpecifiedGenres.iloc[:, -1]

X_train_specifiedGenres, X_test_specifiedGenres, y_train_specifiedGenres, y_test_specifiedGenres = train_test_split(X_specifiedGenres, y_specifiedGenres, test_size=0.3, shuffle=True, random_state=123)

sc = StandardScaler()
X_scaled_train = sc.fit_transform(X_train_specifiedGenres)
X_scaled_test = sc.transform(X_test_specifiedGenres)

pca = PCA(10)
pca.fit(X_scaled_train)
trans_pca = pca.fit_transform(X_scaled_test)


plt.figure(figsize=(8, 6))
for i, genreNum in enumerate(genreNumbers):
    plt.scatter(trans_pca[:,0][y_test_specifiedGenres==genreNum], trans_pca[:,1][y_test_specifiedGenres==genreNum], cmap='jet',label=f'{genreNames[i]}')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()
plt.show()
# Out:
# /var/folders/0x/03rs5r5937b7qn04t9mql34c0000gn/T/ipykernel_23765/1749815973.py:17: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(trans_pca[:,0][y_test_specifiedGenres==genreNum], trans_pca[:,1][y_test_specifiedGenres==genreNum], cmap='jet',label=f'{genreNames[i]}')

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2,perplexity=10)
trans_tsne = tsne.fit_transform(X_scaled_test)


plt.figure(figsize=(8, 6))
for i, genre in enumerate(genreNumbers):
    plt.scatter(trans_tsne[:,0][y_test_specifiedGenres==genre], trans_tsne[:,1][y_test_specifiedGenres==genre], cmap='jet',label=f'{genreNames[i]}')
plt.legend()
plt.show()
# Out:
# /var/folders/0x/03rs5r5937b7qn04t9mql34c0000gn/T/ipykernel_23765/1650034879.py:8: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(trans_tsne[:,0][y_test_specifiedGenres==genre], trans_tsne[:,1][y_test_specifiedGenres==genre], cmap='jet',label=f'{genreNames[i]}')

# %% [markdown]
# Based on the PCA and TSNE graphs, there don't seem to be any separable genres
