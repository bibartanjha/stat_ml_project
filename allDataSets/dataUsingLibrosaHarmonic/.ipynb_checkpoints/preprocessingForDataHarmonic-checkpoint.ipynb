# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
import seaborn as sns

# %%
dataOrig = pd.read_csv("feature_extraction/dataOrig.csv",usecols=lambda column: column != 'filename')

# %%
dataOrig.head()
# Out:
#    chroma_C  chroma_Csharp  chroma_D  chroma_Dsharp  chroma_E  chroma_F  \
# 0  0.391512       0.429697  0.524729       0.385698  0.366340  0.433856
# 1  0.544175       0.420254  0.424198       0.399732  0.300949  0.312941
# 2  0.344232       0.477342  0.461315       0.383294  0.430534  0.360271
# 3  0.392071       0.428158  0.523789       0.385555  0.366227  0.433113
# 4  0.396111       0.442692  0.408399       0.486187  0.353345  0.326342
#
#    chroma_Fsharp  chroma_G  chroma_Gsharp  chroma_A  ...    mfcc12    mfcc13  \
# 0       0.445597  0.593311       0.438685  0.413015  ... -0.841709  2.132198
# 1       0.363381  0.445987       0.342582  0.325424  ...  2.602134  4.048971
# 2       0.595679  0.406584       0.354102  0.464613  ...  0.874806 -1.936897
# 3       0.444056  0.591267       0.437267  0.413407  ... -0.844541  2.099680
# 4       0.372000  0.300399       0.334868  0.334352  ... -0.441958 -1.084060
#
#      mfcc14    mfcc15    mfcc16    mfcc17    mfcc18    mfcc19    mfcc20  genre
# 0  1.083206 -0.077104  0.648073 -1.484534  3.725629  4.553656  4.274244    pop
# 1  2.384604  1.780818 -2.392593 -1.346176 -2.879179 -0.849864 -2.598134    pop
# 2 -2.783130 -2.666644 -3.311479  1.708261 -0.152766  4.846820  2.906235    pop
# 3  1.122588  0.006671  0.748260 -1.474304  3.672843  4.469373  4.198666    pop
# 4 -3.450706 -2.475977 -3.302751 -2.228499 -2.649557 -2.744086  0.305748    pop
#
# [5 rows x 45 columns]

# %% [markdown]
# # Updating datasets y-columns

# %%
mappingGenresToIntegers = {
    'pop': 0,
    'metal': 1,
    'disco': 2,
    'blues': 3,
    'reggae': 4,
    'classical': 5,
    'rock': 6,
    'hiphop': 7,
    'country': 8,
    'jazz': 9
}


dataOrig['genre'] = dataOrig['genre'].map(mappingGenresToIntegers)
dataOrig.head()
# Out:
#    chroma_C  chroma_Csharp  chroma_D  chroma_Dsharp  chroma_E  chroma_F  \
# 0  0.391512       0.429697  0.524729       0.385698  0.366340  0.433856
# 1  0.544175       0.420254  0.424198       0.399732  0.300949  0.312941
# 2  0.344232       0.477342  0.461315       0.383294  0.430534  0.360271
# 3  0.392071       0.428158  0.523789       0.385555  0.366227  0.433113
# 4  0.396111       0.442692  0.408399       0.486187  0.353345  0.326342
#
#    chroma_Fsharp  chroma_G  chroma_Gsharp  chroma_A  ...    mfcc12    mfcc13  \
# 0       0.445597  0.593311       0.438685  0.413015  ... -0.841709  2.132198
# 1       0.363381  0.445987       0.342582  0.325424  ...  2.602134  4.048971
# 2       0.595679  0.406584       0.354102  0.464613  ...  0.874806 -1.936897
# 3       0.444056  0.591267       0.437267  0.413407  ... -0.844541  2.099680
# 4       0.372000  0.300399       0.334868  0.334352  ... -0.441958 -1.084060
#
#      mfcc14    mfcc15    mfcc16    mfcc17    mfcc18    mfcc19    mfcc20  genre
# 0  1.083206 -0.077104  0.648073 -1.484534  3.725629  4.553656  4.274244      0
# 1  2.384604  1.780818 -2.392593 -1.346176 -2.879179 -0.849864 -2.598134      0
# 2 -2.783130 -2.666644 -3.311479  1.708261 -0.152766  4.846820  2.906235      0
# 3  1.122588  0.006671  0.748260 -1.474304  3.672843  4.469373  4.198666      0
# 4 -3.450706 -2.475977 -3.302751 -2.228499 -2.649557 -2.744086  0.305748      0
#
# [5 rows x 45 columns]

# %%
csv_file = 'dataOrig_genreChangedToNumbers.csv'
dataOrig.to_csv(csv_file, index=False)

# %% [markdown]
# # Pre-processing

# %% [markdown]
# ## Standard scaling and train_test_split

# %%
X = dataOrig.iloc[:, :-1]
y = dataOrig.iloc[:, -1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.15, random_state = 42)

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Using heatmap to see what features are too closely correlated, then removing them as necessary

# %%
corr = X.corr()

mask = corr.abs() > 0.9

plt.figure(figsize=(12,10))

sns.heatmap(corr, center=0, mask=mask, square=True, linewidths=.4, annot=True, fmt=".2f", annot_kws={"size": 7}, cbar_kws={"shrink": .5})
plt.xticks(fontsize = 8)
plt.yticks(fontsize = 8)
plt.show()

# %% [markdown]
# Based on the graph above, spectral_centroid, spectral_bandwidth, and spectral_rolloff are all highly correlated. So, we can just keep one of them.

# %% [markdown]
# Based on the graph above, mfcc2 is also highly correlated with spectral_centroid.

# %% [markdown]
# So, we can just keep spectral_centroid and remove the other 3.

# %%
dataOrigWithReducedColumns = dataOrig.drop(columns=['spectral_bandwidth', 'spectral_rolloff', 'mfcc2'])

# %%
dataOrigWithReducedColumns.shape
# Out:
# (1000, 42)

# %%
dataOrigWithReducedColumns.head()
# Out:
#    chroma_C  chroma_Csharp  chroma_D  chroma_Dsharp  chroma_E  chroma_F  \
# 0  0.391512       0.429697  0.524729       0.385698  0.366340  0.433856
# 1  0.544175       0.420254  0.424198       0.399732  0.300949  0.312941
# 2  0.344232       0.477342  0.461315       0.383294  0.430534  0.360271
# 3  0.392071       0.428158  0.523789       0.385555  0.366227  0.433113
# 4  0.396111       0.442692  0.408399       0.486187  0.353345  0.326342
#
#    chroma_Fsharp  chroma_G  chroma_Gsharp  chroma_A  ...    mfcc12    mfcc13  \
# 0       0.445597  0.593311       0.438685  0.413015  ... -0.841709  2.132198
# 1       0.363381  0.445987       0.342582  0.325424  ...  2.602134  4.048971
# 2       0.595679  0.406584       0.354102  0.464613  ...  0.874806 -1.936897
# 3       0.444056  0.591267       0.437267  0.413407  ... -0.844541  2.099680
# 4       0.372000  0.300399       0.334868  0.334352  ... -0.441958 -1.084060
#
#      mfcc14    mfcc15    mfcc16    mfcc17    mfcc18    mfcc19    mfcc20  genre
# 0  1.083206 -0.077104  0.648073 -1.484534  3.725629  4.553656  4.274244      0
# 1  2.384604  1.780818 -2.392593 -1.346176 -2.879179 -0.849864 -2.598134      0
# 2 -2.783130 -2.666644 -3.311479  1.708261 -0.152766  4.846820  2.906235      0
# 3  1.122588  0.006671  0.748260 -1.474304  3.672843  4.469373  4.198666      0
# 4 -3.450706 -2.475977 -3.302751 -2.228499 -2.649557 -2.744086  0.305748      0
#
# [5 rows x 42 columns]

# %%
csv_file = 'dataOrig_reducedColumnsBasedOnCorrelationToEachOther.csv'
dataOrigWithReducedColumns.to_csv(csv_file, index=False)

# %% [markdown]
# ## Randomly choosing features to keep

# %%
columns_to_keep = ['rmse', 'chroma_allPitches', 'tonnetz_allDims', 'spectral_centroid', 'genre']
dataReducedColumns = dataOrig[columns_to_keep]
dataReducedColumns.head()
# Out:
#        rmse  chroma_allPitches  tonnetz_allDims  spectral_centroid  genre
# 0  0.215662           0.433540         0.029555        3151.406048      0
# 1  0.196038           0.386972         0.027165        3206.647959      0
# 2  0.259782           0.423550        -0.016266        3669.810467      0
# 3  0.215733           0.433407         0.028867        3151.342623      0
# 4  0.146568           0.388811        -0.024470        3488.897943      0

# %%
csv_file = 'dataOrig_reducedColumnsRandom.csv'
dataReducedColumns.to_csv(csv_file, index=False)

# %% [markdown]
# ## Only using features most correlated to genre

# %%
correlationMatrix = dataOrig.corr()
correlationWithGenre = correlationMatrix['genre']
correlationWithGenre = correlationWithGenre.drop('genre')

# %%
plt.figure(figsize=(20, 6))
sns.barplot(x=correlationWithGenre.index, y=correlationWithGenre.values)
plt.title('Correlation with Genre')
plt.xlabel('Variable')
plt.ylabel('Correlation')
plt.xticks(rotation=45)
plt.show()

# %%
mostPositive5 = correlationWithGenre.nlargest(5)
print(mostPositive5)
# Out:
# mfcc2              0.328273
# mfcc13             0.121988
# tonnetz_allDims    0.108470
# tonnetz_dim2       0.102610
# mfcc15             0.095681
# Name: genre, dtype: float64

# %%
dataOrigWithMostCorrelatedFeatures = dataOrig[['mfcc2', 'mfcc13', 'tonnetz_allDims', 'tonnetz_dim2', 'mfcc15', 'genre']]
dataOrigWithMostCorrelatedFeatures.head()
# Out:
#        mfcc2    mfcc13  tonnetz_allDims  tonnetz_dim2    mfcc15  genre
# 0  69.775894  2.132198         0.029555      0.078519 -0.077104      0
# 1  65.273964  4.048971         0.027165      0.046163  1.780818      0
# 2  54.295788 -1.936897        -0.016266     -0.046085 -2.666644      0
# 3  69.754700  2.099680         0.028867      0.080946  0.006671      0
# 4  51.834522 -1.084060        -0.024470     -0.068114 -2.475977      0

# %%
csv_file = 'dataOrig_reducedColumnsBasedOnCorrelationToGenre.csv'
dataOrigWithMostCorrelatedFeatures.to_csv(csv_file, index=False)

# %% [markdown]
# ## Removing outliers

# %%
columns = list(range(X.shape[1]))
data_in_columns = X.iloc[:, columns]

# %%
fig, axes = plt.subplots(nrows=5, ncols=6, figsize=(20, 12))

for i, ax in enumerate(axes.flat):
    if i < len(columns):
        ax.boxplot(data_in_columns.iloc[:, i])
        ax.set_title(f'{data_in_columns.columns[i]}')
        ax.axhline(y=data_in_columns.iloc[:, i].median(), color='r')
        ax.set_xlabel(data_in_columns.columns[i])
    else:
        ax.set_visible(False)


plt.show()

# %%
thresholds = data_in_columns.quantile([0.25, 0.75])
iqr = 1.5 * (thresholds.loc[0.75] - thresholds.loc[0.25])

dataWithoutOutliers = dataOrig.copy()

for col in data_in_columns.columns:
    lower = thresholds.loc[0.25, col] - iqr.loc[col]
    upper = thresholds.loc[0.75, col] + iqr.loc[col]
    dataWithoutOutliers[col] = np.where((dataWithoutOutliers[col] < lower) | (dataWithoutOutliers[col] > upper), np.nan, dataWithoutOutliers[col])

dataWithoutOutliers = dataWithoutOutliers.dropna()

# %%
dataWithoutOutliers.shape
# Out:
# (738, 45)

# %%
X = dataWithoutOutliers.iloc[:, :-1]
y = dataWithoutOutliers.iloc[:, -1]

columns = list(range(X.shape[1]))
data_in_columns = X.iloc[:, columns]

fig, axes = plt.subplots(nrows=5, ncols=6, figsize=(20, 12))

for i, ax in enumerate(axes.flat):
    if i < len(columns):
        ax.boxplot(data_in_columns.iloc[:, i])
        ax.set_title(f'{data_in_columns.columns[i]}')
        ax.axhline(y=data_in_columns.iloc[:, i].median(), color='r')
        ax.set_xlabel(data_in_columns.columns[i])
    else:
        ax.set_visible(False)


plt.show()

# %%
dataWithoutOutliers.head()
# Out:
#    chroma_C  chroma_Csharp  chroma_D  chroma_Dsharp  chroma_E  chroma_F  \
# 0  0.391512       0.429697  0.524729       0.385698  0.366340  0.433856
# 1  0.544175       0.420254  0.424198       0.399732  0.300949  0.312941
# 2  0.344232       0.477342  0.461315       0.383294  0.430534  0.360271
# 3  0.392071       0.428158  0.523789       0.385555  0.366227  0.433113
# 4  0.396111       0.442692  0.408399       0.486187  0.353345  0.326342
#
#    chroma_Fsharp  chroma_G  chroma_Gsharp  chroma_A  ...    mfcc12    mfcc13  \
# 0       0.445597  0.593311       0.438685  0.413015  ... -0.841709  2.132198
# 1       0.363381  0.445987       0.342582  0.325424  ...  2.602134  4.048971
# 2       0.595679  0.406584       0.354102  0.464613  ...  0.874806 -1.936897
# 3       0.444056  0.591267       0.437267  0.413407  ... -0.844541  2.099680
# 4       0.372000  0.300399       0.334868  0.334352  ... -0.441958 -1.084060
#
#      mfcc14    mfcc15    mfcc16    mfcc17    mfcc18    mfcc19    mfcc20  genre
# 0  1.083206 -0.077104  0.648073 -1.484534  3.725629  4.553656  4.274244      0
# 1  2.384604  1.780818 -2.392593 -1.346176 -2.879179 -0.849864 -2.598134      0
# 2 -2.783130 -2.666644 -3.311479  1.708261 -0.152766  4.846820  2.906235      0
# 3  1.122588  0.006671  0.748260 -1.474304  3.672843  4.469373  4.198666      0
# 4 -3.450706 -2.475977 -3.302751 -2.228499 -2.649557 -2.744086  0.305748      0
#
# [5 rows x 45 columns]

# %%
dataWithoutOutliers.shape
# Out:
# (738, 45)

# %%
csv_file = 'dataOrig_withoutOutliers.csv'
dataWithoutOutliers.to_csv(csv_file, index=False)

# %%
labels = [
    'pop',
    'metal',
    'disco',
    'blues',
    'reggae',
    'classical',
    'rock',
    'hiphop',
    'country',
    'jazz'
]

sizes = np.unique(y,return_counts=True)[1]

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%')

plt.show()

# %% [markdown]
# ## Only testing with certain genres

# %% [markdown]
# ### Part 1 - Randomly separating the genres

# %%
dataMetalOrReggae = dataOrig[dataOrig.iloc[:, -1].isin([1, 4])]
dataMetalOrReggae.head()
# Out:
#      chroma_C  chroma_Csharp  chroma_D  chroma_Dsharp  chroma_E  chroma_F  \
# 100  0.197645       0.253560  0.530577       0.676284  0.603167  0.416595
# 101  0.555681       0.554876  0.646270       0.524454  0.509183  0.502343
# 102  0.412719       0.367689  0.338250       0.434104  0.592827  0.422646
# 103  0.491189       0.567155  0.589308       0.469433  0.495655  0.505738
# 104  0.455604       0.366034  0.405422       0.474057  0.520951  0.465351
#
#      chroma_Fsharp  chroma_G  chroma_Gsharp  chroma_A  ...     mfcc12  \
# 100       0.469057  0.586434       0.534654  0.490844  ...   5.675272
# 101       0.473830  0.506142       0.482216  0.537800  ...  13.682774
# 102       0.298741  0.387750       0.440941  0.507487  ...   5.380840
# 103       0.592601  0.645546       0.479652  0.420058  ...  11.690027
# 104       0.575677  0.598739       0.511573  0.469804  ...  12.519557
#
#         mfcc13     mfcc14     mfcc15    mfcc16     mfcc17    mfcc18    mfcc19  \
# 100  -6.760373  -0.477520  -0.283377  5.876618  -3.955661 -1.294904  3.513754
# 101  -8.369143   7.960476  -6.297391  8.126195  -4.967942  6.167456  0.367815
# 102  -2.997646   2.975844  -5.824659  3.941298  -5.992150 -1.972414  2.391165
# 103  -9.267028   2.800758  -4.434639  5.498721  -6.276275  3.827627 -0.428164
# 104 -18.503286  10.830414 -13.701790  4.867671 -11.978018  1.642398 -7.640708
#
#        mfcc20  genre
# 100 -1.250803      1
# 101  2.692185      1
# 102 -3.859571      1
# 103  4.651005      1
# 104  2.228671      1
#
# [5 rows x 45 columns]

# %%
csv_file = 'dataOrig_metal_reggae.csv'
dataMetalOrReggae.to_csv(csv_file, index=False)

# %%
dataPopOrDisco = dataOrig[dataOrig.iloc[:, -1].isin([0, 2])]
dataPopOrDisco.head()
# Out:
#    chroma_C  chroma_Csharp  chroma_D  chroma_Dsharp  chroma_E  chroma_F  \
# 0  0.391512       0.429697  0.524729       0.385698  0.366340  0.433856
# 1  0.544175       0.420254  0.424198       0.399732  0.300949  0.312941
# 2  0.344232       0.477342  0.461315       0.383294  0.430534  0.360271
# 3  0.392071       0.428158  0.523789       0.385555  0.366227  0.433113
# 4  0.396111       0.442692  0.408399       0.486187  0.353345  0.326342
#
#    chroma_Fsharp  chroma_G  chroma_Gsharp  chroma_A  ...    mfcc12    mfcc13  \
# 0       0.445597  0.593311       0.438685  0.413015  ... -0.841709  2.132198
# 1       0.363381  0.445987       0.342582  0.325424  ...  2.602134  4.048971
# 2       0.595679  0.406584       0.354102  0.464613  ...  0.874806 -1.936897
# 3       0.444056  0.591267       0.437267  0.413407  ... -0.844541  2.099680
# 4       0.372000  0.300399       0.334868  0.334352  ... -0.441958 -1.084060
#
#      mfcc14    mfcc15    mfcc16    mfcc17    mfcc18    mfcc19    mfcc20  genre
# 0  1.083206 -0.077104  0.648073 -1.484534  3.725629  4.553656  4.274244      0
# 1  2.384604  1.780818 -2.392593 -1.346176 -2.879179 -0.849864 -2.598134      0
# 2 -2.783130 -2.666644 -3.311479  1.708261 -0.152766  4.846820  2.906235      0
# 3  1.122588  0.006671  0.748260 -1.474304  3.672843  4.469373  4.198666      0
# 4 -3.450706 -2.475977 -3.302751 -2.228499 -2.649557 -2.744086  0.305748      0
#
# [5 rows x 45 columns]

# %%
csv_file = 'dataOrig_pop_disco.csv'
dataPopOrDisco.to_csv(csv_file, index=False)

# %%
dataRockOrCountry = dataOrig[dataOrig.iloc[:, -1].isin([6, 8])]
dataRockOrCountry.head()
# Out:
#      chroma_C  chroma_Csharp  chroma_D  chroma_Dsharp  chroma_E  chroma_F  \
# 600  0.394059       0.350094  0.455285       0.364732  0.564776  0.350641
# 601  0.338946       0.288647  0.318111       0.380675  0.602792  0.458370
# 602  0.465354       0.395574  0.452946       0.348066  0.293899  0.265719
# 603  0.563634       0.504108  0.516254       0.358893  0.344161  0.366845
# 604  0.544997       0.313132  0.314725       0.225910  0.378880  0.547735
#
#      chroma_Fsharp  chroma_G  chroma_Gsharp  chroma_A  ...     mfcc12  \
# 600       0.432859  0.344357       0.416916  0.694107  ...  -0.017735
# 601       0.379182  0.356645       0.397867  0.506765  ...  10.380571
# 602       0.299983  0.422719       0.330956  0.396222  ...   9.204597
# 603       0.407865  0.474683       0.347970  0.385865  ...  -0.580254
# 604       0.607361  0.536730       0.297946  0.286034  ...   5.409077
#
#        mfcc13    mfcc14     mfcc15    mfcc16     mfcc17    mfcc18     mfcc19  \
# 600 -4.127094 -5.765080  -1.067484  2.295977  -1.575925 -3.856851  -6.144731
# 601 -8.630905  7.146430 -11.839626  3.169745 -10.362882  1.510586 -10.358376
# 602 -6.970773  6.322464  -9.627941  0.514762 -12.772728 -4.880867  -2.517167
# 603 -0.529924  2.343106  -0.366673 -4.108472  -3.857270 -3.911095  -5.780759
# 604 -4.123982  2.983528  -5.321567 -8.830944 -11.077198 -3.206342   3.858218
#
#        mfcc20  genre
# 600 -5.379481      6
# 601 -2.479376      6
# 602 -3.125364      6
# 603 -4.329663      6
# 604  3.554310      6
#
# [5 rows x 45 columns]

# %%
csv_file = 'dataOrig_rock_country.csv'
dataRockOrCountry.to_csv(csv_file, index=False)

# %% [markdown]
# ### Using PCA and TSNE to analyze which features to keep

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA, FactorAnalysis

X = dataOrig.iloc[:, :-1]
y = dataOrig.iloc[:, -1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True, random_state=123)

sc = StandardScaler()
X_scaled_train = sc.fit_transform(X_train)
X_scaled_test = sc.transform(X_test)

pca = PCA()
transformed = pca.fit_transform(X_scaled_train)

exp_var_pca = pca.explained_variance_ratio_
cum_sum_eigenvalues = np.cumsum(exp_var_pca)

plt.bar(range(0,len(exp_var_pca)), exp_var_pca, alpha=0.5, align='center')
plt.ylabel('Explained variance ratio')
plt.xlabel('Principal component index')
plt.title("Individual explained variance")
plt.tight_layout()
plt.show()

# %%
plt.step(range(0,len(cum_sum_eigenvalues)), cum_sum_eigenvalues, where='mid',label='Cumulative explained variance')
plt.hlines(0.8, xmin=0, xmax=len(cum_sum_eigenvalues), color='red', linewidth=.6)
plt.hlines(0.9, xmin=0, xmax=len(cum_sum_eigenvalues), color='red', linewidth=.6)
plt.ylabel('Explained variance ratio')
plt.xlabel('Principal component index')
plt.title("Cumulative explained variance")
plt.show()

# %% [markdown]
# The main difference between the two plots lies in what they visualize:
#
# Individual Explained Variance Plot:
#
# The first plot, generated with plt.bar(), displays the explained variance ratio for each individual principal component.
# Each bar in this plot represents the proportion of total variance explained by a single principal component.
# This plot helps in understanding the relative importance of each principal component in explaining the variance in the data.
# Cumulative Explained Variance Plot:
#
# The second plot, created with plt.step(), illustrates the cumulative explained variance ratio.
# It shows how much of the total variance in the dataset is explained as the number of principal components increases.
# The steps in this plot indicate the incremental contribution of each principal component to the total explained variance.
# Horizontal lines are added at specific percentages (e.g., 80% and 90%) to indicate where certain thresholds of cumulative explained variance are reached.
# This plot helps in determining the number of principal components needed to retain a certain amount of variance in the data, which is crucial for dimensionality reduction or feature selection purposes.

# %%
n_comps = 10
pca = PCA(n_components=n_comps)
X_train_pca_transformed = pca.fit_transform(X_scaled_train)
X_train_pca_transformed = pd.DataFrame(X_train_pca_transformed, index=X_train.index, columns=[f'PCA_{n}' for n in range(1,n_comps+1)])
X_train_pca_transformed.head()
# Out:
#         PCA_1     PCA_2     PCA_3     PCA_4     PCA_5     PCA_6     PCA_7  \
# 498 -2.279369 -1.331791 -1.034818 -0.484528  1.332786 -1.241179  0.827503
# 243 -2.408802 -2.457327 -0.478971 -0.868342  0.296579 -1.102044 -2.364968
# 314 -0.366524 -2.724045  1.143544  2.213343 -0.928145 -1.546495  1.212752
# 202 -4.174295 -3.201025  2.492699  1.730772 -1.740897 -0.740596  0.165967
# 300 -2.592888 -3.121328  0.924810  0.525014 -0.762732  0.007898 -0.094630
#
#         PCA_8     PCA_9    PCA_10
# 498 -0.471788  0.033642 -0.219904
# 243 -0.076524  0.137484 -1.997231
# 314  3.315430  1.670899 -0.472726
# 202  1.011243  1.277440 -0.852711
# 300  1.394864  0.897970 -0.732105

# %%
combined = pd.concat([X_train_pca_transformed, y_train], axis=1)
combined.head()
# Out:
#         PCA_1     PCA_2     PCA_3     PCA_4     PCA_5     PCA_6     PCA_7  \
# 498 -2.279369 -1.331791 -1.034818 -0.484528  1.332786 -1.241179  0.827503
# 243 -2.408802 -2.457327 -0.478971 -0.868342  0.296579 -1.102044 -2.364968
# 314 -0.366524 -2.724045  1.143544  2.213343 -0.928145 -1.546495  1.212752
# 202 -4.174295 -3.201025  2.492699  1.730772 -1.740897 -0.740596  0.165967
# 300 -2.592888 -3.121328  0.924810  0.525014 -0.762732  0.007898 -0.094630
#
#         PCA_8     PCA_9    PCA_10  genre
# 498 -0.471788  0.033642 -0.219904      4
# 243 -0.076524  0.137484 -1.997231      2
# 314  3.315430  1.670899 -0.472726      3
# 202  1.011243  1.277440 -0.852711      2
# 300  1.394864  0.897970 -0.732105      3

# %%
csv_file = 'dataOrig_pcaUsingAllFeatures.csv'
combined.to_csv(csv_file, index=False)

# %%
X = data_scaled[:, :-1]
y = data_scaled[:, -1]

n_comps = 3
tsne = TSNE(n_components=n_comps,perplexity=10)
X_train_tsne_transformed = tsne.fit_transform(X_scaled_train)
X_train_tsne_transformed = pd.DataFrame(X_train_tsne_transformed, index=X_train.index, columns=[f'TSNE_{n}' for n in range(1,n_comps+1)])
X_train_tsne_transformed.head()
# Out:
#         TSNE_1     TSNE_2    TSNE_3
# 498  -5.924394  -1.738624  5.528903
# 243  -8.568893  -5.785326  4.591673
# 314  -5.618346 -12.431746  0.806070
# 202 -10.346687 -14.793427  3.223194
# 300  -8.044891 -12.927318 -0.755767

# %%
combinedTSNE = pd.concat([X_train_tsne_transformed, y_train], axis=1)
combinedTSNE.head()
# Out:
#         TSNE_1     TSNE_2    TSNE_3  genre
# 498  -5.924394  -1.738624  5.528903      4
# 243  -8.568893  -5.785326  4.591673      2
# 314  -5.618346 -12.431746  0.806070      3
# 202 -10.346687 -14.793427  3.223194      2
# 300  -8.044891 -12.927318 -0.755767      3

# %%
csv_file = 'dataOrig_tsneUsingAllFeatures.csv'
combinedTSNE.to_csv(csv_file, index=False)

# %% [markdown]
# ### Also going to use PCA and TSNE to figure out which genres to use for most variance in data

# %%
pca = PCA(10)
pca.fit(X_train)
trans_pca = pca.fit_transform(X_test)

genres=['pop', 'metal', 'disco', 'blues', 'reggae', 'classical', 'rock', 'hiphop', 'country', 'jazz']


plt.figure(figsize=(8, 6))
for i in range(10):
    plt.scatter(trans_pca[:,0][y_test==i], trans_pca[:,1][y_test==i], cmap='jet',label=f'{genres[i]}')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()
plt.show()
# Out:
# /var/folders/0x/03rs5r5937b7qn04t9mql34c0000gn/T/ipykernel_644/1904545730.py:10: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(trans_pca[:,0][y_test==i], trans_pca[:,1][y_test==i], cmap='jet',label=f'{genres[i]}')

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2,perplexity=10)
trans_tsne = tsne.fit_transform(X_test)

genres=['pop', 'metal', 'disco', 'blues', 'reggae', 'classical', 'rock', 'hiphop', 'country', 'jazz']


plt.figure(figsize=(8, 6))
for i in range(10):
    plt.scatter(trans_tsne[:,0][y_test==i], trans_tsne[:,1][y_test==i], cmap='jet',label=f'{genres[i]}')
plt.legend()
plt.show()
# Out:
# /var/folders/0x/03rs5r5937b7qn04t9mql34c0000gn/T/ipykernel_644/3138321272.py:10: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(trans_tsne[:,0][y_test==i], trans_tsne[:,1][y_test==i], cmap='jet',label=f'{genres[i]}')

# %% [markdown]
# Based on the two graphs, it seems that pop, metal, and classical are all separate clusters and there is a lot of variance

# %%
genreNames = ['pop', 'metal', 'classical']
genreNumbers = [0, 1, 5]


dataSpecifiedGenres = dataOrig[dataOrig.iloc[:, -1].isin(genreNumbers)]
dataSpecifiedGenres.shape
# Out:
# (300, 45)

# %%
dataSpecifiedGenres.head()
# Out:
#    chroma_C  chroma_Csharp  chroma_D  chroma_Dsharp  chroma_E  chroma_F  \
# 0  0.391512       0.429697  0.524729       0.385698  0.366340  0.433856
# 1  0.544175       0.420254  0.424198       0.399732  0.300949  0.312941
# 2  0.344232       0.477342  0.461315       0.383294  0.430534  0.360271
# 3  0.392071       0.428158  0.523789       0.385555  0.366227  0.433113
# 4  0.396111       0.442692  0.408399       0.486187  0.353345  0.326342
#
#    chroma_Fsharp  chroma_G  chroma_Gsharp  chroma_A  ...    mfcc12    mfcc13  \
# 0       0.445597  0.593311       0.438685  0.413015  ... -0.841709  2.132198
# 1       0.363381  0.445987       0.342582  0.325424  ...  2.602134  4.048971
# 2       0.595679  0.406584       0.354102  0.464613  ...  0.874806 -1.936897
# 3       0.444056  0.591267       0.437267  0.413407  ... -0.844541  2.099680
# 4       0.372000  0.300399       0.334868  0.334352  ... -0.441958 -1.084060
#
#      mfcc14    mfcc15    mfcc16    mfcc17    mfcc18    mfcc19    mfcc20  genre
# 0  1.083206 -0.077104  0.648073 -1.484534  3.725629  4.553656  4.274244      0
# 1  2.384604  1.780818 -2.392593 -1.346176 -2.879179 -0.849864 -2.598134      0
# 2 -2.783130 -2.666644 -3.311479  1.708261 -0.152766  4.846820  2.906235      0
# 3  1.122588  0.006671  0.748260 -1.474304  3.672843  4.469373  4.198666      0
# 4 -3.450706 -2.475977 -3.302751 -2.228499 -2.649557 -2.744086  0.305748      0
#
# [5 rows x 45 columns]

# %%
csv_file = 'dataOrig_pop_metal_classical.csv'
dataSpecifiedGenres.to_csv(csv_file, index=False)

# %%
X_specifiedGenres = dataSpecifiedGenres.iloc[:, :-1]
y_specifiedGenres = dataSpecifiedGenres.iloc[:, -1]

X_train_specifiedGenres, X_test_specifiedGenres, y_train_specifiedGenres, y_test_specifiedGenres = train_test_split(X_specifiedGenres, y_specifiedGenres, test_size=0.3, shuffle=True, random_state=123)

sc = StandardScaler()
X_scaled_train = sc.fit_transform(X_train_specifiedGenres)
X_scaled_test = sc.transform(X_test_specifiedGenres)

pca = PCA(10)
pca.fit(X_scaled_train)
trans_pca = pca.fit_transform(X_scaled_test)


plt.figure(figsize=(8, 6))
for i, genreNum in enumerate(genreNumbers):
    plt.scatter(trans_pca[:,0][y_test_specifiedGenres==genreNum], trans_pca[:,1][y_test_specifiedGenres==genreNum], cmap='jet',label=f'{genreNames[i]}')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()
plt.show()
# Out:
# /var/folders/0x/03rs5r5937b7qn04t9mql34c0000gn/T/ipykernel_644/1749815973.py:17: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(trans_pca[:,0][y_test_specifiedGenres==genreNum], trans_pca[:,1][y_test_specifiedGenres==genreNum], cmap='jet',label=f'{genreNames[i]}')

# %% [markdown]
# # Also going to use PCA and TSNE to figure out which genres to use for most variance in data. Same section as above, but this time we'll split dataOrig into 2 subsections of genres

# %% [markdown]
# ## genres = ['classical','hiphop','metal', 'disco', 'reggae']

# %%
genreNames = ['classical','hiphop','metal', 'disco', 'reggae']
genreNumbers = [5, 7, 1, 2, 4]

dataSpecifiedGenres = dataOrig[dataOrig.iloc[:, -1].isin(genreNumbers)]
dataSpecifiedGenres.shape
# Out:
# (500, 45)

# %%
dataSpecifiedGenres.head()
# Out:
#      chroma_C  chroma_Csharp  chroma_D  chroma_Dsharp  chroma_E  chroma_F  \
# 100  0.197645       0.253560  0.530577       0.676284  0.603167  0.416595
# 101  0.555681       0.554876  0.646270       0.524454  0.509183  0.502343
# 102  0.412719       0.367689  0.338250       0.434104  0.592827  0.422646
# 103  0.491189       0.567155  0.589308       0.469433  0.495655  0.505738
# 104  0.455604       0.366034  0.405422       0.474057  0.520951  0.465351
#
#      chroma_Fsharp  chroma_G  chroma_Gsharp  chroma_A  ...     mfcc12  \
# 100       0.469057  0.586434       0.534654  0.490844  ...   5.675272
# 101       0.473830  0.506142       0.482216  0.537800  ...  13.682774
# 102       0.298741  0.387750       0.440941  0.507487  ...   5.380840
# 103       0.592601  0.645546       0.479652  0.420058  ...  11.690027
# 104       0.575677  0.598739       0.511573  0.469804  ...  12.519557
#
#         mfcc13     mfcc14     mfcc15    mfcc16     mfcc17    mfcc18    mfcc19  \
# 100  -6.760373  -0.477520  -0.283377  5.876618  -3.955661 -1.294904  3.513754
# 101  -8.369143   7.960476  -6.297391  8.126195  -4.967942  6.167456  0.367815
# 102  -2.997646   2.975844  -5.824659  3.941298  -5.992150 -1.972414  2.391165
# 103  -9.267028   2.800758  -4.434639  5.498721  -6.276275  3.827627 -0.428164
# 104 -18.503286  10.830414 -13.701790  4.867671 -11.978018  1.642398 -7.640708
#
#        mfcc20  genre
# 100 -1.250803      1
# 101  2.692185      1
# 102 -3.859571      1
# 103  4.651005      1
# 104  2.228671      1
#
# [5 rows x 45 columns]

# %%
X_specifiedGenres = dataSpecifiedGenres.iloc[:, :-1]
y_specifiedGenres = dataSpecifiedGenres.iloc[:, -1]

X_train_specifiedGenres, X_test_specifiedGenres, y_train_specifiedGenres, y_test_specifiedGenres = train_test_split(X_specifiedGenres, y_specifiedGenres, test_size=0.3, shuffle=True, random_state=123)

sc = StandardScaler()
X_scaled_train = sc.fit_transform(X_train_specifiedGenres)
X_scaled_test = sc.transform(X_test_specifiedGenres)

pca = PCA(10)
pca.fit(X_scaled_train)
trans_pca = pca.fit_transform(X_scaled_test)


plt.figure(figsize=(8, 6))
for i, genreNum in enumerate(genreNumbers):
    plt.scatter(trans_pca[:,0][y_test_specifiedGenres==genreNum], trans_pca[:,1][y_test_specifiedGenres==genreNum], cmap='jet',label=f'{genreNames[i]}')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()
plt.show()
# Out:
# /var/folders/0x/03rs5r5937b7qn04t9mql34c0000gn/T/ipykernel_644/1749815973.py:17: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(trans_pca[:,0][y_test_specifiedGenres==genreNum], trans_pca[:,1][y_test_specifiedGenres==genreNum], cmap='jet',label=f'{genreNames[i]}')

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2,perplexity=10)
trans_tsne = tsne.fit_transform(X_scaled_test)


plt.figure(figsize=(8, 6))
for i, genre in enumerate(genreNumbers):
    plt.scatter(trans_tsne[:,0][y_test_specifiedGenres==genre], trans_tsne[:,1][y_test_specifiedGenres==genre], cmap='jet',label=f'{genreNames[i]}')
plt.legend()
plt.show()
# Out:
# /var/folders/0x/03rs5r5937b7qn04t9mql34c0000gn/T/ipykernel_644/1650034879.py:8: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(trans_tsne[:,0][y_test_specifiedGenres==genre], trans_tsne[:,1][y_test_specifiedGenres==genre], cmap='jet',label=f'{genreNames[i]}')

# %% [markdown]
# Based on the PCA and TSNE graphs, it seems classical and metal would be well seperable

# %%
genreNames = ['classical', 'metal']
genreNumbers = [5, 1]

dataSpecifiedGenres = dataOrig[dataOrig.iloc[:, -1].isin(genreNumbers)]
dataSpecifiedGenres.head()
# Out:
#      chroma_C  chroma_Csharp  chroma_D  chroma_Dsharp  chroma_E  chroma_F  \
# 100  0.197645       0.253560  0.530577       0.676284  0.603167  0.416595
# 101  0.555681       0.554876  0.646270       0.524454  0.509183  0.502343
# 102  0.412719       0.367689  0.338250       0.434104  0.592827  0.422646
# 103  0.491189       0.567155  0.589308       0.469433  0.495655  0.505738
# 104  0.455604       0.366034  0.405422       0.474057  0.520951  0.465351
#
#      chroma_Fsharp  chroma_G  chroma_Gsharp  chroma_A  ...     mfcc12  \
# 100       0.469057  0.586434       0.534654  0.490844  ...   5.675272
# 101       0.473830  0.506142       0.482216  0.537800  ...  13.682774
# 102       0.298741  0.387750       0.440941  0.507487  ...   5.380840
# 103       0.592601  0.645546       0.479652  0.420058  ...  11.690027
# 104       0.575677  0.598739       0.511573  0.469804  ...  12.519557
#
#         mfcc13     mfcc14     mfcc15    mfcc16     mfcc17    mfcc18    mfcc19  \
# 100  -6.760373  -0.477520  -0.283377  5.876618  -3.955661 -1.294904  3.513754
# 101  -8.369143   7.960476  -6.297391  8.126195  -4.967942  6.167456  0.367815
# 102  -2.997646   2.975844  -5.824659  3.941298  -5.992150 -1.972414  2.391165
# 103  -9.267028   2.800758  -4.434639  5.498721  -6.276275  3.827627 -0.428164
# 104 -18.503286  10.830414 -13.701790  4.867671 -11.978018  1.642398 -7.640708
#
#        mfcc20  genre
# 100 -1.250803      1
# 101  2.692185      1
# 102 -3.859571      1
# 103  4.651005      1
# 104  2.228671      1
#
# [5 rows x 45 columns]

# %%
csv_file = 'dataOrig_metal_classical.csv'
dataSpecifiedGenres.to_csv(csv_file, index=False)

# %%
X_specifiedGenres = dataSpecifiedGenres.iloc[:, :-1]
y_specifiedGenres = dataSpecifiedGenres.iloc[:, -1]

X_train_specifiedGenres, X_test_specifiedGenres, y_train_specifiedGenres, y_test_specifiedGenres = train_test_split(X_specifiedGenres, y_specifiedGenres, test_size=0.3, shuffle=True, random_state=123)

sc = StandardScaler()
X_scaled_train = sc.fit_transform(X_train_specifiedGenres)
X_scaled_test = sc.transform(X_test_specifiedGenres)

n_comps = 10
pca = PCA(n_components=n_comps)
X_train_pca_transformed = pca.fit_transform(X_scaled_train)
X_train_pca_transformed = pd.DataFrame(X_train_pca_transformed, index=X_train_specifiedGenres.index, columns=[f'PCA_{n}' for n in range(1,n_comps+1)])
combined = pd.concat([X_train_pca_transformed, y_train_specifiedGenres], axis=1)
combined.head()
# Out:
#         PCA_1     PCA_2     PCA_3     PCA_4     PCA_5     PCA_6     PCA_7  \
# 181  5.247803 -0.026050 -0.027489 -0.140394 -0.351474  0.825433 -0.222018
# 507 -3.582147 -1.327366 -1.356361  0.487537 -1.160926  0.533567 -0.826916
# 512 -4.021728 -0.552765 -0.133678  2.202016  0.778532 -0.312361  0.856978
# 545 -4.149868  1.527501  0.851864 -2.267270  0.324477 -0.115662 -0.101948
# 108  3.636086 -1.332922 -1.278494  0.398646  1.096060 -1.075819 -0.558418
#
#         PCA_8     PCA_9    PCA_10  genre
# 181  0.219077  0.157236  1.029878      1
# 507  1.436072  0.469459 -0.071673      5
# 512 -1.131885  1.590562  0.799160      5
# 545  0.600343  0.142446 -0.374759      5
# 108  0.353076 -0.257446  0.622551      1

# %%
csv_file = 'dataOrig_pcaUsingMetalAndClassical.csv'
combined.to_csv(csv_file, index=False)

# %% [markdown]
# ## genres = ['pop','rock','country', 'jazz', 'blues']

# %%
genreNames = ['pop','rock','country', 'jazz', 'blues']
genreNumbers = [0, 6, 8, 9, 3]

dataSpecifiedGenres = dataOrig[dataOrig.iloc[:, -1].isin(genreNumbers)]
dataSpecifiedGenres.shape
# Out:
# (500, 45)

# %%
dataSpecifiedGenres.head()
# Out:
#    chroma_C  chroma_Csharp  chroma_D  chroma_Dsharp  chroma_E  chroma_F  \
# 0  0.391512       0.429697  0.524729       0.385698  0.366340  0.433856
# 1  0.544175       0.420254  0.424198       0.399732  0.300949  0.312941
# 2  0.344232       0.477342  0.461315       0.383294  0.430534  0.360271
# 3  0.392071       0.428158  0.523789       0.385555  0.366227  0.433113
# 4  0.396111       0.442692  0.408399       0.486187  0.353345  0.326342
#
#    chroma_Fsharp  chroma_G  chroma_Gsharp  chroma_A  ...    mfcc12    mfcc13  \
# 0       0.445597  0.593311       0.438685  0.413015  ... -0.841709  2.132198
# 1       0.363381  0.445987       0.342582  0.325424  ...  2.602134  4.048971
# 2       0.595679  0.406584       0.354102  0.464613  ...  0.874806 -1.936897
# 3       0.444056  0.591267       0.437267  0.413407  ... -0.844541  2.099680
# 4       0.372000  0.300399       0.334868  0.334352  ... -0.441958 -1.084060
#
#      mfcc14    mfcc15    mfcc16    mfcc17    mfcc18    mfcc19    mfcc20  genre
# 0  1.083206 -0.077104  0.648073 -1.484534  3.725629  4.553656  4.274244      0
# 1  2.384604  1.780818 -2.392593 -1.346176 -2.879179 -0.849864 -2.598134      0
# 2 -2.783130 -2.666644 -3.311479  1.708261 -0.152766  4.846820  2.906235      0
# 3  1.122588  0.006671  0.748260 -1.474304  3.672843  4.469373  4.198666      0
# 4 -3.450706 -2.475977 -3.302751 -2.228499 -2.649557 -2.744086  0.305748      0
#
# [5 rows x 45 columns]

# %%
X_specifiedGenres = dataSpecifiedGenres.iloc[:, :-1]
y_specifiedGenres = dataSpecifiedGenres.iloc[:, -1]

X_train_specifiedGenres, X_test_specifiedGenres, y_train_specifiedGenres, y_test_specifiedGenres = train_test_split(X_specifiedGenres, y_specifiedGenres, test_size=0.3, shuffle=True, random_state=123)

sc = StandardScaler()
X_scaled_train = sc.fit_transform(X_train_specifiedGenres)
X_scaled_test = sc.transform(X_test_specifiedGenres)

pca = PCA(10)
pca.fit(X_scaled_train)
trans_pca = pca.fit_transform(X_scaled_test)


plt.figure(figsize=(8, 6))
for i, genreNum in enumerate(genreNumbers):
    plt.scatter(trans_pca[:,0][y_test_specifiedGenres==genreNum], trans_pca[:,1][y_test_specifiedGenres==genreNum], cmap='jet',label=f'{genreNames[i]}')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()
plt.show()
# Out:
# /var/folders/0x/03rs5r5937b7qn04t9mql34c0000gn/T/ipykernel_644/1749815973.py:17: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(trans_pca[:,0][y_test_specifiedGenres==genreNum], trans_pca[:,1][y_test_specifiedGenres==genreNum], cmap='jet',label=f'{genreNames[i]}')

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2,perplexity=10)
trans_tsne = tsne.fit_transform(X_scaled_test)


plt.figure(figsize=(8, 6))
for i, genre in enumerate(genreNumbers):
    plt.scatter(trans_tsne[:,0][y_test_specifiedGenres==genre], trans_tsne[:,1][y_test_specifiedGenres==genre], cmap='jet',label=f'{genreNames[i]}')
plt.legend()
plt.show()
# Out:
# /var/folders/0x/03rs5r5937b7qn04t9mql34c0000gn/T/ipykernel_644/1650034879.py:8: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(trans_tsne[:,0][y_test_specifiedGenres==genre], trans_tsne[:,1][y_test_specifiedGenres==genre], cmap='jet',label=f'{genreNames[i]}')

# %% [markdown]
# Based on the PCA and TSNE graphs, it seems pop and blues would be well seperable

# %%
genreNames = ['pop', 'blues']
genreNumbers = [0, 3]

dataSpecifiedGenres = dataOrig[dataOrig.iloc[:, -1].isin(genreNumbers)]
dataSpecifiedGenres.head()
# Out:
#    chroma_C  chroma_Csharp  chroma_D  chroma_Dsharp  chroma_E  chroma_F  \
# 0  0.391512       0.429697  0.524729       0.385698  0.366340  0.433856
# 1  0.544175       0.420254  0.424198       0.399732  0.300949  0.312941
# 2  0.344232       0.477342  0.461315       0.383294  0.430534  0.360271
# 3  0.392071       0.428158  0.523789       0.385555  0.366227  0.433113
# 4  0.396111       0.442692  0.408399       0.486187  0.353345  0.326342
#
#    chroma_Fsharp  chroma_G  chroma_Gsharp  chroma_A  ...    mfcc12    mfcc13  \
# 0       0.445597  0.593311       0.438685  0.413015  ... -0.841709  2.132198
# 1       0.363381  0.445987       0.342582  0.325424  ...  2.602134  4.048971
# 2       0.595679  0.406584       0.354102  0.464613  ...  0.874806 -1.936897
# 3       0.444056  0.591267       0.437267  0.413407  ... -0.844541  2.099680
# 4       0.372000  0.300399       0.334868  0.334352  ... -0.441958 -1.084060
#
#      mfcc14    mfcc15    mfcc16    mfcc17    mfcc18    mfcc19    mfcc20  genre
# 0  1.083206 -0.077104  0.648073 -1.484534  3.725629  4.553656  4.274244      0
# 1  2.384604  1.780818 -2.392593 -1.346176 -2.879179 -0.849864 -2.598134      0
# 2 -2.783130 -2.666644 -3.311479  1.708261 -0.152766  4.846820  2.906235      0
# 3  1.122588  0.006671  0.748260 -1.474304  3.672843  4.469373  4.198666      0
# 4 -3.450706 -2.475977 -3.302751 -2.228499 -2.649557 -2.744086  0.305748      0
#
# [5 rows x 45 columns]

# %%
csv_file = 'dataOrig_pop_blues.csv'
dataSpecifiedGenres.to_csv(csv_file, index=False)

# %%
X_specifiedGenres = dataSpecifiedGenres.iloc[:, :-1]
y_specifiedGenres = dataSpecifiedGenres.iloc[:, -1]

X_train_specifiedGenres, X_test_specifiedGenres, y_train_specifiedGenres, y_test_specifiedGenres = train_test_split(X_specifiedGenres, y_specifiedGenres, test_size=0.3, shuffle=True, random_state=123)

sc = StandardScaler()
X_scaled_train = sc.fit_transform(X_train_specifiedGenres)
X_scaled_test = sc.transform(X_test_specifiedGenres)

n_comps = 10
pca = PCA(n_components=n_comps)
X_train_pca_transformed = pca.fit_transform(X_scaled_train)
X_train_pca_transformed = pd.DataFrame(X_train_pca_transformed, index=X_train_specifiedGenres.index, columns=[f'PCA_{n}' for n in range(1,n_comps+1)])
combined = pd.concat([X_train_pca_transformed, y_train_specifiedGenres], axis=1)
combined.head()
# Out:
#         PCA_1     PCA_2     PCA_3     PCA_4     PCA_5     PCA_6     PCA_7  \
# 81  -5.371573  1.231430 -0.074582 -0.012813 -0.754818 -0.500622 -1.407200
# 307  8.446558 -2.848867 -2.603214 -4.672153 -1.989798  2.320351 -1.842532
# 312  1.914270  3.420145 -1.588006  1.362401  0.494032 -1.688118  0.008080
# 345  5.036083 -3.155490  3.898513 -0.409705  0.457182 -1.772775 -0.753364
# 8   -4.012970 -1.351164  0.395891 -0.764109 -1.028406  0.194397 -0.173695
#
#         PCA_8     PCA_9    PCA_10  genre
# 81  -2.154873 -0.215668  0.351276      0
# 307 -0.642594  0.764362 -0.100621      3
# 312 -0.786605  0.120569  1.046240      3
# 345 -1.561498  0.422332 -0.243027      3
# 8    0.479453 -1.102773  0.237215      0

# %%
csv_file = 'dataOrig_pcaUsingPopAndBlues.csv'
combined.to_csv(csv_file, index=False)
