# %%
# !pip install librosa
# Out:
# Collecting librosa
#   Obtaining dependency information for librosa from https://files.pythonhosted.org/packages/e2/a2/4f639c1168d7aada749a896afb4892a831e2041bebdcf636aebfe9e86556/librosa-0.10.1-py3-none-any.whl.metadata
#   Downloading librosa-0.10.1-py3-none-any.whl.metadata (8.3 kB)
# Collecting audioread>=2.1.9 (from librosa)
#   Obtaining dependency information for audioread>=2.1.9 from https://files.pythonhosted.org/packages/57/8d/30aa32745af16af0a9a650115fbe81bde7c610ed5c21b381fca0196f3a7f/audioread-3.0.1-py3-none-any.whl.metadata
#   Downloading audioread-3.0.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /Users/sayantanj/anaconda3/lib/python3.11/site-packages (from librosa) (1.24.3)
# Requirement already satisfied: scipy>=1.2.0 in /Users/sayantanj/anaconda3/lib/python3.11/site-packages (from librosa) (1.11.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /Users/sayantanj/anaconda3/lib/python3.11/site-packages (from librosa) (1.3.0)
# Requirement already satisfied: joblib>=0.14 in /Users/sayantanj/anaconda3/lib/python3.11/site-packages (from librosa) (1.2.0)
# Requirement already satisfied: decorator>=4.3.0 in /Users/sayantanj/anaconda3/lib/python3.11/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in /Users/sayantanj/anaconda3/lib/python3.11/site-packages (from librosa) (0.57.1)
# Collecting soundfile>=0.12.1 (from librosa)
#   Obtaining dependency information for soundfile>=0.12.1 from https://files.pythonhosted.org/packages/71/87/31d2b9ed58975cec081858c01afaa3c43718eb0f62b5698a876d94739ad0/soundfile-0.12.1-py2.py3-none-macosx_11_0_arm64.whl.metadata
#   Downloading soundfile-0.12.1-py2.py3-none-macosx_11_0_arm64.whl.metadata (14 kB)
# Collecting pooch>=1.0 (from librosa)
#   Obtaining dependency information for pooch>=1.0 from https://files.pythonhosted.org/packages/f4/72/8ae0f1ba4ce6a4f6d4d01a60a9fdf690fde188c45c1872b0b4ddb0607ace/pooch-1.8.1-py3-none-any.whl.metadata
#   Downloading pooch-1.8.1-py3-none-any.whl.metadata (9.5 kB)
# Collecting soxr>=0.3.2 (from librosa)
#   Obtaining dependency information for soxr>=0.3.2 from https://files.pythonhosted.org/packages/d0/79/c93daceac24cd6830333d9f3d04716115240ef3be4e8d8ece511afbcf417/soxr-0.3.7-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading soxr-0.3.7-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Requirement already satisfied: typing-extensions>=4.1.1 in /Users/sayantanj/anaconda3/lib/python3.11/site-packages (from librosa) (4.7.1)
# Requirement already satisfied: lazy-loader>=0.1 in /Users/sayantanj/anaconda3/lib/python3.11/site-packages (from librosa) (0.2)
# Requirement already satisfied: msgpack>=1.0 in /Users/sayantanj/anaconda3/lib/python3.11/site-packages (from librosa) (1.0.3)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /Users/sayantanj/anaconda3/lib/python3.11/site-packages (from numba>=0.51.0->librosa) (0.40.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/sayantanj/anaconda3/lib/python3.11/site-packages (from pooch>=1.0->librosa) (3.10.0)
# Requirement already satisfied: packaging>=20.0 in /Users/sayantanj/anaconda3/lib/python3.11/site-packages (from pooch>=1.0->librosa) (23.1)
# Requirement already satisfied: requests>=2.19.0 in /Users/sayantanj/anaconda3/lib/python3.11/site-packages (from pooch>=1.0->librosa) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/sayantanj/anaconda3/lib/python3.11/site-packages (from scikit-learn>=0.20.0->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in /Users/sayantanj/anaconda3/lib/python3.11/site-packages (from soundfile>=0.12.1->librosa) (1.15.1)
# Requirement already satisfied: pycparser in /Users/sayantanj/anaconda3/lib/python3.11/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sayantanj/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sayantanj/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sayantanj/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sayantanj/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2023.7.22)
# Downloading librosa-0.10.1-py3-none-any.whl (253 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.7/253.7 kB 4.9 MB/s eta 0:00:00a 0:00:01
# Downloading audioread-3.0.1-py3-none-any.whl (23 kB)
# Downloading pooch-1.8.1-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 kB 12.0 MB/s eta 0:00:00
# Downloading soundfile-0.12.1-py2.py3-none-macosx_11_0_arm64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 17.1 MB/s eta 0:00:00a 0:00:01
# Downloading soxr-0.3.7-cp311-cp311-macosx_11_0_arm64.whl (390 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.5/390.5 kB 13.1 MB/s eta 0:00:00
# Installing collected packages: soxr, audioread, soundfile, pooch, librosa
# Successfully installed audioread-3.0.1 librosa-0.10.1 pooch-1.8.1 soundfile-0.12.1 soxr-0.3.7

# %%
import os
import librosa
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
pathToAllFiles = 'genres'
allGenres = os.listdir(pathToAllFiles)
#print(allGenres)

allFeatures = []
labels = []
for genre in allGenres:
    pathToGenreFiles = os.path.join(pathToAllFiles, genre)
    #print(pathToGenreFiles)
    for file in os.listdir(pathToGenreFiles):
        #print(file)
        pathToFile = os.path.join(pathToGenreFiles, file)
        #print(pathToFile)
        
        
        try:
            audio, sr = librosa.load(file_path, res_type='kaiser_fast')
            chroma = librosa.feature.chroma_stft(y=audio, sr=sr)
            chroma_mean = np.mean(chroma, axis=1)
            
            tonnetz = librosa.feature.tonnetz(y=librosa.effects.harmonic(audio), sr=sr)
            tonnetz_mean = np.mean(tonnetz, axis=1)
            
            allFeatures.append(np.hstack((chroma_mean.reshape(-1, 1), tonnetz_mean.reshape(-1, 1))))
            labels.append(genre)


        except Exception as e:
            continue 
        
print(np.vstack(allFeatures))
# Out:
# [0.3150313  0.2577859  0.2512394  0.24356036 0.2623939  0.29013008
#  0.30809528 0.3875138  0.3696429  0.4524908  0.38674662 0.24779822]
#
# [0.3150313  0.2577859  0.2512394  0.24356036 0.2623939  0.29013008
#  0.30809528 0.3875138  0.3696429  0.4524908  0.38674662 0.24779822]
#
# [0.3150313  0.2577859  0.2512394  0.24356036 0.2623939  0.29013008
#  0.30809528 0.3875138  0.3696429  0.4524908  0.38674662 0.24779822]
#
# [0.3150313  0.2577859  0.2512394  0.24356036 0.2623939  0.29013008
#  0.30809528 0.3875138  0.3696429  0.4524908  0.38674662 0.24779822]
#
# [0.3150313  0.2577859  0.2512394  0.24356036 0.2623939  0.29013008
#  0.30809528 0.3875138  0.3696429  0.4524908  0.38674662 0.24779822]
#
# [0.3150313  0.2577859  0.2512394  0.24356036 0.2623939  0.29013008
#  0.30809528 0.3875138  0.3696429  0.4524908  0.38674662 0.24779822]
#
# [0.3150313  0.2577859  0.2512394  0.24356036 0.2623939  0.29013008
#  0.30809528 0.3875138  0.3696429  0.4524908  0.38674662 0.24779822]
#
# [0.3150313  0.2577859  0.2512394  0.24356036 0.2623939  0.29013008
#  0.30809528 0.3875138  0.3696429  0.4524908  0.38674662 0.24779822]
#
# [0.3150313  0.2577859  0.2512394  0.24356036 0.2623939  0.29013008
#  0.30809528 0.3875138  0.3696429  0.4524908  0.38674662 0.24779822]
#
# [0.3150313  0.2577859  0.2512394  0.24356036 0.2623939  0.29013008
#  0.30809528 0.3875138  0.3696429  0.4524908  0.38674662 0.24779822]
#
# [0.3150313  0.2577859  0.2512394  0.24356036 0.2623939  0.29013008
#  0.30809528 0.3875138  0.3696429  0.4524908  0.38674662 0.24779822]
#
# [0.3150313  0.2577859  0.2512394  0.24356036 0.2623939  0.29013008
#  0.30809528 0.3875138  0.3696429  0.4524908  0.38674662 0.24779822]
#
# [0.3150313  0.2577859  0.2512394  0.24356036 0.2623939  0.29013008
#  0.30809528 0.3875138  0.3696429  0.4524908  0.38674662 0.24779822]
#
# [0.3150313  0.2577859  0.2512394  0.24356036 0.2623939  0.29013008
#  0.30809528 0.3875138  0.3696429  0.4524908  0.38674662 0.24779822]
#
# [0.3150313  0.2577859  0.2512394  0.24356036 0.2623939  0.29013008
#  0.30809528 0.3875138  0.3696429  0.4524908  0.38674662 0.24779822]
#
# [0.3150313  0.2577859  0.2512394  0.24356036 0.2623939  0.29013008
#  0.30809528 0.3875138  0.3696429  0.4524908  0.38674662 0.24779822]
#
# [0.3150313  0.2577859  0.2512394  0.24356036 0.2623939  0.29013008
#  0.30809528 0.3875138  0.3696429  0.4524908  0.38674662 0.24779822]
#
# [0.3150313  0.2577859  0.2512394  0.24356036 0.2623939  0.29013008
#  0.30809528 0.3875138  0.3696429  0.4524908  0.38674662 0.24779822]
#
# [0.3150313  0.2577859  0.2512394  0.24356036 0.2623939  0.29013008
#  0.30809528 0.3875138  0.3696429  0.4524908  0.38674662 0.24779822]
#
# [0.3150313  0.2577859  0.2512394  0.24356036 0.2623939  0.29013008
#  0.30809528 0.3875138  0.3696429  0.4524908  0.38674662 0.24779822]
#
# [0.3150313  0.2577859  0.2512394  0.24356036 0.2623939  0.29013008
#  0.30809528 0.3875138  0.3696429  0.4524908  0.38674662 0.24779822]
#
# [0.3150313  0.2577859  0.2512394  0.24356036 0.2623939  0.29013008
#  0.30809528 0.3875138  0.3696429  0.4524908  0.38674662 0.24779822]
#
# [0.3150313  0.2577859  0.2512394  0.24356036 0.2623939  0.29013008
#  0.30809528 0.3875138  0.3696429  0.4524908  0.38674662 0.24779822]
#
# [0.3150313  0.2577859  0.2512394  0.24356036 0.2623939  0.29013008
#  0.30809528 0.3875138  0.3696429  0.4524908  0.38674662 0.24779822]
#
# [0.3150313  0.2577859  0.2512394  0.24356036 0.2623939  0.29013008
#  0.30809528 0.3875138  0.3696429  0.4524908  0.38674662 0.24779822]
#
# [0.3150313  0.2577859  0.2512394  0.24356036 0.2623939  0.29013008
#  0.30809528 0.3875138  0.3696429  0.4524908  0.38674662 0.24779822]
#
# [0.3150313  0.2577859  0.2512394  0.24356036 0.2623939  0.29013008
#  0.30809528 0.3875138  0.3696429  0.4524908  0.38674662 0.24779822]
#
# [0.3150313  0.2577859  0.2512394  0.24356036 0.2623939  0.29013008
#  0.30809528 0.3875138  0.3696429  0.4524908  0.38674662 0.24779822]
#
# [0.3150313  0.2577859  0.2512394  0.24356036 0.2623939  0.29013008
#  0.30809528 0.3875138  0.3696429  0.4524908  0.38674662 0.24779822]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 15
#      13 y, sr = librosa.load(file_path, res_type='kaiser_fast')
#      14 chroma = librosa.feature.chroma_stft(y=y, sr=sr)
# ---> 15 tonnetz = librosa.feature.tonnetz(y=librosa.effects.harmonic(y), sr=sr)
#      16 #print(chroma)
#      17 #print(tonnetz)
#      18 print(chroma.mean(axis=1))
#
# File ~/anaconda3/lib/python3.11/site-packages/librosa/effects.py:142, in harmonic(y, **kwargs)
#     139 stft = core.stft(y)
#     141 # Remove percussives
# --> 142 stft_harm = decompose.hpss(stft, **kwargs)[0]
#     144 # Invert the STFTs
#     145 y_harm = core.istft(stft_harm, dtype=y.dtype, length=y.shape[-1])
#
# File ~/anaconda3/lib/python3.11/site-packages/librosa/decompose.py:393, in hpss(S, kernel_size, power, mask, margin)
#     390 harm[:] = median_filter(S, size=harm_shape, mode="reflect")
#     392 perc = np.empty_like(S)
# --> 393 perc[:] = median_filter(S, size=perc_shape, mode="reflect")
#     395 split_zeros = margin_harm == 1 and margin_perc == 1
#     397 mask_harm = util.softmask(
#     398     harm, perc * margin_harm, power=power, split_zeros=split_zeros
#     399 )
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/ndimage/_filters.py:1518, in median_filter(input, size, footprint, output, mode, cval, origin, axes)
#    1471 @_ni_docstrings.docfiller
#    1472 def median_filter(input, size=None, footprint=None, output=None,
#    1473                   mode="reflect", cval=0.0, origin=0, *, axes=None):
#    1474     """
#    1475     Calculate a multidimensional median filter.
#    1476
#    (...)
#    1516     >>> plt.show()
#    1517     """
# -> 1518     return _rank_filter(input, 0, size, footprint, output, mode, cval,
#    1519                         origin, 'median', axes=axes)
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/ndimage/_filters.py:1419, in _rank_filter(input, rank, size, footprint, output, mode, cval, origin, operation, axes)
#    1415     raise RuntimeError(
#    1416         "A sequence of modes is not supported by non-separable rank "
#    1417         "filters")
#    1418 mode = _ni_support._extend_mode_to_code(mode)
# -> 1419 _nd_image.rank_filter(input, rank, footprint, output, mode, cval,
#    1420                       origins)
#    1421 if temp_needed:
#    1422     temp[...] = output
#
# KeyboardInterrupt:
